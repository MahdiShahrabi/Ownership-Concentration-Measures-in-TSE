# %%
## Loading Libraries
import pandas as pd
import numpy as np
import sys
import jdatetime as jd
import os
import pickle
from scipy import stats
# import power_index_calculator as px
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Loading Data

# %%
df[df.sum_over1>=90]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6fc22e06e608> in <module>
# ----> 1 df[df.sum_over1>=90]
#
# NameError: name 'df' is not defined

# %%
## Loading DATA

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data\Avergae day Volume - yearly")
temp = pd.read_csv("list_of_total_average6.csv",index_col=0)
    
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
df = pd.read_csv("data_owenership98_blnc98.csv",index_col=0)

# %%
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
df = pd.read_csv("data_owenership98_blnc98.csv",index_col=0)
print('Number of Observation is: ',len(df),'\n')

## Filtering Data
theta_sum1 = 90
theta_holder = 3


filtered = df[df.sum_over1>=theta_sum1]
df = df[df.sum_over1<=theta_sum1]
print(len(filtered),' is deleted becaause their sum_above1% is equalt to or more than ',theta_sum1,'%')

filtered = df[df.Num_holders<=theta_holder]
df = df[df.Num_holders>theta_holder]
print(len(filtered),' is deleted becaause their number of holder is less or equal than ',theta_holder)

print('\nNumber of remained Observation is: ',len(df))
# Out:
# Number of Observation is:  722
#
# 122  is deleted becaause their sum_above1% is equalt to or more than  90 %
# 251  is deleted becaause their number of holder is less or equal than  3
#
# Number of remained Observation is:  282

# %%
df.loc[df['SSCO']==np.inf,'SSCO'] = np.nan
df.loc[df['Num_holders']==1,'First_Second'] = np.nan
df.loc[df['Num_holders']<4,'First_Sumtwofour'] = np.nan
df.loc[df['Num_holders']==1,'Gini'] = np.nan
df.loc[df['Num_holders']<5,'Sumfive'] = np.nan

# %%
df[df.First_Sumtwofour>10]
# Out:
#      Symbol        Id_tse  sum_over1  Num_holders  Largest_Owner  \
# 18     اطلس  1.142794e+16      80.34          4.0          73.12
# 28     اوان  6.984714e+16      60.39          4.0          56.91
# 53    بهپاک  1.274673e+16      72.76          4.0          66.22
# 187   دشیمی  3.360321e+16      84.00          4.0          78.07
# 261   سهگمت  4.128452e+16      78.56          5.0          70.35
# 305  شوینده  3.493306e+15      81.02          4.0          76.69
# 311   شپمچا  4.434510e+16      85.07          4.0          81.30
# 346   غویتا  3.784279e+16      84.81          4.0          77.48
# 367  فباهنر  6.677202e+16      81.84          4.0          77.64
# 582     چدن  1.232952e+16      73.55          4.0          69.82
#
#      First_Second  First_Sumtwofour  Sumfive      Gini  Herfindhal  ...  BZCL  \
# 18      19.343915         10.127424      NaN  0.900838    0.536711  ...   1.0
# 28      46.647541         16.353448      NaN  0.924712    0.324280  ...   1.0
# 53      29.043860         10.125382      NaN  0.882719    0.439939  ...   1.0
# 187     27.982079         13.165261      NaN  0.918175    0.610786  ...   1.0
# 261     27.057692         10.740458    78.56  0.879837    0.496655  ...   1.0
# 305     43.573864         17.711316      NaN  0.932856    0.588776  ...   1.0
# 311     59.343066         21.564987      NaN  0.942322    0.661445  ...   1.0
# 346     20.827957         10.570259      NaN  0.906143    0.602480  ...   1.0
# 367     40.863158         18.485714      NaN  0.938335    0.603424  ...   1.0
# 582     50.230216         18.718499      NaN  0.934920    0.487951  ...   1.0
#
#      BZCO  BZDL  Tot_asset    Tot_lib    Capital  Equity_at_year_end  \
# 18    0.0   1.0        NaN        NaN        NaN                 NaN
# 28    0.0   1.0        NaN        NaN        NaN                 NaN
# 53    0.0   1.0  3606540.0  2511748.0   500000.0           1094792.0
# 187   0.0   1.0  1711380.0  1245460.0   255000.0            465920.0
# 261   0.0   1.0  2837824.0  1581918.0   502900.0           1255906.0
# 305   0.0   1.0  3999403.0   410110.0  1000000.0           3589293.0
# 311   0.0   1.0  1478731.0  1101628.0    30000.0            377103.0
# 346   0.0   1.0  4154136.0  2040958.0   600000.0           2113178.0
# 367   0.0   1.0  6965882.0  4854284.0  1125000.0           2111598.0
# 582   0.0   1.0        NaN        NaN        NaN                 NaN
#
#      Debt_Equity  Debt_Equity_normal  book_value
# 18           NaN                 NaN         NaN
# 28           NaN                 NaN         NaN
# 53     3606540.0            894792.0   1094792.0
# 187    1711380.0            346070.0    465920.0
# 261    2837824.0           1031577.0   1255906.0
# 305    3999403.0           1939292.0   3589293.0
# 311    1478731.0           -198510.0    377103.0
# 346    4154136.0           1067160.0   2113178.0
# 367    6965882.0           1409598.0   2111598.0
# 582          NaN                 NaN         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Summary Stat of Data

# %%
OC_list = ['Largest_Owner','First_Second','First_Sumtwofour','Sumfive',
           'Gini','Herfindhal','SSCL','SSCO','SSDL','SSDO','BZCL','BZCO','BZDL']
df[OC_list].describe()
# Out:
#        Largest_Owner  First_Second  First_Sumtwofour     Sumfive        Gini  \
# count     282.000000    282.000000        282.000000  199.000000  282.000000
# mean       39.136631      5.499447          2.699731   64.223216    0.618824
# std        19.178589      7.870683          3.229442   17.917631    0.191532
# min         2.600000      1.000000          0.333333   20.230000    0.076027
# 25%        21.372500      1.539105          0.775866   50.300000    0.495038
# 50%        39.965000      2.509329          1.477448   68.250000    0.623910
# 75%        52.217500      5.747868          3.239208   78.920000    0.783520
# max        81.300000     59.343066         21.564987   89.990000    0.942322
#
#        Herfindhal        SSCL        SSCO        SSDL        SSDO        BZCL  \
# count  282.000000  282.000000  272.000000  275.000000  275.000000  282.000000
# mean     0.223606    0.591739    0.192085    0.606980    0.186982    0.650833
# std      0.151617    0.344782    0.201166    0.340421    0.199677    0.363882
# min      0.001532    0.026420    0.000000    0.026669    0.000000    0.026489
# 25%      0.099214    0.249247    0.000000    0.265625    0.000000    0.279678
# 50%      0.205743    0.550309    0.164604    0.578632    0.157882    0.810043
# 75%      0.297281    1.000000    0.294053    1.000000    0.283744    1.000000
# max      0.661445    1.000000    0.923518    1.000000    0.922627    1.000000
#
#              BZCO        BZDL
# count  282.000000  282.000000
# mean     0.161218    0.747217
# std      0.204050    0.318760
# min      0.000000    0.061563
# 25%      0.000000    0.478775
# 50%      0.046917    1.000000
# 75%      0.282881    1.000000
# max      0.923344    1.000000

# %%
df[np.logical_and(~pd.isnull(df.book_value),~pd.isnull(df.sum_over1))]
# Out:
#        Symbol        Id_tse  sum_over1  Num_holders  Largest_Owner  \
# 2       آ س پ  1.761747e+16      79.08          5.0          40.26
# 5       آریان  6.506180e+15      67.90         21.0          10.38
# 22       افرا  5.279290e+16      89.23          5.0          27.21
# 43       برکت  3.455724e+16      89.25          4.0          78.50
# 48      بموتو  2.208688e+16      79.07          4.0          42.68
# ..        ...           ...        ...          ...            ...
# 639      کچاد  1.802780e+16      80.49          6.0          39.26
# 641      کگاز  6.234680e+16      76.84          5.0          50.99
# 644  کی بی سی  6.297732e+16      88.01          4.0          76.07
# 647     کیمیا  2.781484e+16      73.79          5.0          40.90
# 652     گکوثر  6.659911e+16      79.74          3.0          46.00
#
#      First_Second  First_Sumtwofour  Sumfive      Gini  Herfindhal  ...  \
# 2        2.689379          1.083132    79.08  0.529274    0.210784  ...
# 5        1.108974          0.479446    36.93  0.420619    0.036699  ...
# 22       1.360500          0.453500    89.23  0.282304    0.194446  ...
# 43      13.149079          7.302326    89.25  0.866293    0.620932  ...
# 48       2.184237          1.172850    79.07  0.496986    0.235340  ...
# ..            ...               ...      ...       ...         ...  ...
# 639      2.286546          1.048891    78.98  0.581414    0.204909  ...
# 641      3.202889          2.051911    76.84  0.739654    0.290429  ...
# 644      8.713631          6.371022    88.01  0.874635    0.586809  ...
# 647      2.031793          1.284144    73.79  0.668790    0.219216  ...
# 652      1.425914          1.363367    79.74  0.558315    0.315890  ...
#
#          BZCL      BZCO      BZDL   Tot_asset     Tot_lib     Capital  \
# 2    0.617099  0.234059  1.000000   1465029.0    518844.0    800000.0
# 5    0.112467  0.313345  0.164849  27829680.0   2803931.0  19817375.0
# 22   0.444208  0.076744  0.500000   1334792.0    459833.0    625000.0
# 43   1.000000  0.000000  1.000000  11645928.0   6903657.0   3400000.0
# 48   0.804572  0.144047  1.000000   5565966.0   2746561.0    680400.0
# ..        ...       ...       ...         ...         ...         ...
# 639  0.565833  0.219819  0.750000  98882021.0  26036825.0  33500000.0
# 641  1.000000  0.000000  1.000000   1935303.0   1126184.0    450000.0
# 644  1.000000  0.000000  1.000000   2501153.0   1866691.0    240000.0
# 647  0.837944  0.128431  1.000000   1267241.0    406487.0    230400.0
# 652  0.978808  0.018608  1.000000    404599.0    192500.0    110000.0
#
#      Equity_at_year_end  Debt_Equity  Debt_Equity_normal  book_value
# 2              946185.0    1465029.0            946185.0    946185.0
# 5            25025749.0   27829680.0          24332141.0  25025749.0
# 22             874959.0    1334792.0            806209.0    874959.0
# 43            4742271.0   11645928.0           4209434.0   4742271.0
# 48            2819405.0    5565966.0           1458605.0   2819405.0
# ..                  ...          ...                 ...         ...
# 639          72845196.0   98882021.0          49395196.0  72845196.0
# 641            809119.0    1935303.0            606619.0    809119.0
# 644            634462.0    2501153.0            771262.0    634462.0
# 647            860754.0    1267241.0            710994.0    860754.0
# 652            212099.0     404599.0            122999.0    212099.0
#
# [181 rows x 24 columns]

# %%
df[df.sum_over1>90]
# Out:
#            Symbol        Id_tse  sum_over1  Num_holders  Largest_Owner  \
# 0     اعتضاد غدیر  3.497388e+16      99.89          1.0          99.89
# 3           آتیمس  2.283933e+16      94.92          6.0          79.34
# 6            آساس  6.668266e+16      91.71          2.0          82.01
# 7            آسام  3.659297e+16      95.28          3.0          92.83
# 10         آسیاتک  1.407969e+16      99.97          3.0          79.97
# ..            ...           ...        ...          ...            ...
# 630         کنگار  5.325443e+15      99.35          1.0          99.35
# 633          کوثر  2.227560e+16      91.22          8.0          19.77
# 643          کگهر  3.070314e+16      94.75          4.0          28.37
# 649         گنگین  5.947011e+16      99.25          2.0          79.25
# 650        گوهران  6.501880e+16      91.98          2.0          90.78
#
#      First_Second  First_Sumtwofour  Sumfive      Gini  Herfindhal  ...  \
# 0             NaN          1.000000    99.89       NaN    0.997801  ...
# 3       19.687345          6.786997    93.72  0.832322    0.634914  ...
# 6        8.454639               NaN    91.71  0.788464    0.681973  ...
# 7       65.836879         37.889796    95.28  0.963371    0.862048  ...
# 10       7.997000          3.998500    99.97  0.699910    0.659520  ...
# ..            ...               ...      ...       ...         ...  ...
# 630           NaN          1.000000    99.35       NaN    0.987042  ...
# 633      1.343984          0.447995    73.69  0.285683    0.124859  ...
# 643      1.089896          0.427388    94.75  0.114864    0.229892  ...
# 649      3.962500               NaN    99.25  0.596977    0.668056  ...
# 650     75.650000               NaN    91.98  0.973907    0.824245  ...
#
#         BZCL      BZCO     BZDL   Tot_asset    Tot_lib    Capital  \
# 0    1.00000  0.000000  1.00000         NaN        NaN        NaN
# 3    1.00000  0.000000  1.00000         NaN        NaN        NaN
# 6    1.00000  0.000000  1.00000         NaN        NaN        NaN
# 7    1.00000  0.000000  1.00000         NaN        NaN        NaN
# 10   1.00000  0.000000  1.00000         NaN        NaN        NaN
# ..       ...       ...      ...         ...        ...        ...
# 630  1.00000  0.000000  1.00000         NaN        NaN        NaN
# 633  0.21375  0.074252  0.23134         NaN        NaN        NaN
# 643  0.34802  0.154200  0.50000         NaN        NaN        NaN
# 649  1.00000  0.000000  1.00000  13914324.0  7466542.0  3000000.0
# 650  1.00000  0.000000  1.00000   4293982.0   466899.0  2000000.0
#
#      Equity_at_year_end  Debt_Equity  Debt_Equity_normal  book_value
# 0                   NaN          NaN                 NaN         NaN
# 3                   NaN          NaN                 NaN         NaN
# 6                   NaN          NaN                 NaN         NaN
# 7                   NaN          NaN                 NaN         NaN
# 10                  NaN          NaN                 NaN         NaN
# ..                  ...          ...                 ...         ...
# 630                 NaN          NaN                 NaN         NaN
# 633                 NaN          NaN                 NaN         NaN
# 643                 NaN          NaN                 NaN         NaN
# 649           6447782.0   13914324.0           3957782.0   6447782.0
# 650           3827083.0    4293982.0           3027083.0   3827083.0
#
# [122 rows x 24 columns]

# %% [markdown]
# ## Wilcoxon Test

# %%
out = pd.DataFrame()
out_list = list()

for i in range(len(OC_list)-1):
    x = df[OC_list[i]]
    
    for j in range(1,len(OC_list)):
        y = df[OC_list[j]]
        
        zipped = [ (a,b) for a,b in zip(x,y) if a is not np.nan and b is not np.nan]
        x =  [a for a,b in zipped]
        y =  [b for a,b in zipped]

        w,p = stats.wilcoxon(x=x,y=y)
        if j>i:
            if p<0.05 and p>0.01:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))+'*'
            elif p<0.01:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))+'**'
            else:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))

            out_list.append([OC_list[j],OC_list[i],w,p])
        else:
            out.loc[OC_list[j],OC_list[i]] = ''
        
out

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
out.to_csv('Wilcoxon.csv')
# Out:
# C:\Users\Mahdi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2882: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# C:\Users\Mahdi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2883: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
#                  Largest_Owner First_Second First_Sumtwofour Sumfive  \
# First_Second             0.0**
# First_Sumtwofour         0.0**        0.0**
# Sumfive                 31.5**        0.0**            0.0**
# Gini                     0.0**        0.0**           76.0**   0.0**
# Herfindhal               0.0**        0.0**            0.0**   0.0**
# SSCL                     0.0**        0.0**            0.0**   0.0**
# SSCO                     0.0**        0.0**           44.0**   0.0**
# SSDL                     0.0**        0.0**            0.0**   0.0**
# SSDO                     0.0**        0.0**           43.0**   0.0**
# BZCL                     0.0**        0.0**            0.0**   0.0**
# BZCO                     0.0**        0.0**           68.0**   0.0**
# BZDL                     0.0**        0.0**            3.0**   0.0**
#
#                        Gini Herfindhal       SSCL       SSCO       SSDL  \
# First_Second
# First_Sumtwofour
# Sumfive
# Gini
# Herfindhal         3218.0**
# SSCL              54809.0**     97.0**
# SSCO               5398.0**  39255.0**  12623.0**
# SSDL              50337.0**     93.0**   6195.0**  11430.0**
# SSDO               5315.0**  38719.0**  12050.0**   8861.0**  11975.0**
# BZCL              38034.0**    149.0**   6146.0**   9245.0**   5920.0**
# BZCO               5116.0**  33179.0**  11036.0**   9017.0**   9993.0**
# BZDL              16406.0**     92.0**    408.0**   2563.0**    399.0**
#
#                       SSDO      BZCL      BZCO
# First_Second
# First_Sumtwofour
# Sumfive
# Gini
# Herfindhal
# SSCL
# SSCO
# SSDL
# SSDO
# BZCL              8789.0**
# BZCO              9894.0**  8950.0**
# BZDL              2201.0**    60.0**  3000.0**

# %% [markdown]
# ## Spearman Correlation Rank Test

# %%
out = pd.DataFrame()
out_list = list()

for i in range(len(OC_list)-1):
    x = df[OC_list[i]]
    
    for j in range(1,len(OC_list)):
        y = df[OC_list[j]]
        
        zipped = [ (a,b) for a,b in zip(x,y) if a is not np.nan and b is not np.nan]
        x =  [a for a,b in zipped]
        y =  [b for a,b in zipped]
        
        if j>i:
            rho,p = stats.spearmanr(x,y,nan_policy='omit')
            if p<0.05 and p>0.01:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))+'*'
            elif p<0.01:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))+'**'
            else:
                out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))

            out_list.append([OC_list[j],OC_list[i],w,p])
        else:
            out.loc[OC_list[j],OC_list[i]] = ''
out

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
out.to_csv('Spearman.csv')
# Out:
#                  Largest_Owner First_Second First_Sumtwofour    Sumfive  \
# First_Second          0.7529**
# First_Sumtwofour      0.5754**     0.9545**
# Sumfive                0.732**     0.1745**         0.1525**
# Gini                  0.7708**     0.8922**         0.9305**    0.243**
# Herfindhal            0.9815**     0.6237**         0.4852**   0.8223**
# SSCL                  0.9197**     0.7067**         0.6623**   0.6137**
# SSCO                 -0.8508**    -0.5359**        -0.4375**  -0.7017**
# SSDL                  0.9154**     0.7013**         0.6493**    0.594**
# SSDO                 -0.8437**     -0.537**        -0.4288**  -0.6735**
# BZCL                  0.9001**     0.7484**         0.7035**   0.5539**
# BZCO                 -0.8467**    -0.6559**        -0.5921**   -0.588**
# BZDL                  0.6656**       0.68**         0.7568**   0.2817**
#
#                        Gini Herfindhal       SSCL       SSCO       SSDL  \
# First_Second
# First_Sumtwofour
# Sumfive
# Gini
# Herfindhal         0.6647**
# SSCL                0.723**   0.8846**
# SSCO              -0.5634**  -0.8581**  -0.9161**
# SSDL               0.7127**   0.8789**      1.0**  -0.9225**
# SSDO              -0.5554**   -0.848**  -0.9067**    0.993**  -0.9063**
# BZCL               0.7471**   0.8518**   0.9835**  -0.8785**   0.9829**
# BZCO              -0.6687**  -0.8226**  -0.9186**   0.9164**  -0.9194**
# BZDL               0.6501**   0.5941**   0.7399**  -0.4795**   0.7262**
#
#                        SSDO       BZCL       BZCO
# First_Second
# First_Sumtwofour
# Sumfive
# Gini
# Herfindhal
# SSCL
# SSCO
# SSDL
# SSDO
# BZCL              -0.8702**
# BZCO                0.909**  -0.9276**
# BZDL              -0.4551**    0.776**  -0.6365**
