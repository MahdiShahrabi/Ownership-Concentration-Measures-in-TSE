# %%
## Loading Libraries
import pandas as pd
import numpy as np
import sys
import jdatetime as jd
import os
import pickle
from scipy import stats
# import power_index_calculator as px
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Loading Data

# %%
## Loading DATA
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
df = pd.read_csv("data_owenership97_blnc98.csv",index_col=0)
OC_list = ['Largest_Owner','First_Second','First_Sumtwofour','Sumfive',
           'Gini','Herfindhal','SSCL','SSCO','SSDL','SSDO','BZCL','BZCO','BZDL']

# %% [markdown]
# ## Summary Stat of Data

# %%
df[OC_list].describe()
# Out:
#        Largest_Owner  First_Second  First_Sumtwofour     Sumfive        Gini  \
# count     605.000000    605.000000        605.000000  605.000000  605.000000
# mean       51.590182      8.668201          6.351044   72.329438    0.570338
# std        25.570321     14.791023         12.476705   22.381365    0.292798
# min         3.300000      1.000000          0.333333    4.860000    0.000000
# 25%        32.550000      1.343984          1.000000   59.450000    0.402205
# 50%        50.990000      2.717549          1.597795   77.140000    0.636136
# 75%        68.290000      7.838612          5.069212   89.970000    0.798753
# max        99.990000     96.000000         92.660000  100.000000    0.978646
#
#        Herfindhal        SSCL        SSCO        SSDL        SSDO        BZCL  \
# count  605.000000  605.000000  605.000000  595.000000  595.000000  605.000000
# mean     0.363948    0.722935         inf    0.734562    0.133156    0.775352
# std      0.269813    0.340039         NaN    0.334095    0.216318    0.336476
# min      0.001612    0.033779    0.000000    0.034106    0.000000    0.034103
# 25%      0.159124    0.387573    0.000000    0.398958    0.000000    0.469759
# 50%      0.302100    1.000000    0.000000    1.000000    0.000000    1.000000
# 75%      0.489934    1.000000    0.230602    1.000000    0.206133    1.000000
# max      0.999800    1.000000         inf    1.000000    0.948917    1.000000
#
#              BZCO        BZDL
# count  605.000000  605.000000
# mean     0.102388    0.847912
# std      0.201890    0.279722
# min      0.000000    0.060942
# 25%      0.000000    0.900000
# 50%      0.000000    1.000000
# 75%      0.102258    1.000000
# max      0.947457    1.000000

# %% [markdown]
# ## Wilcoxon Test

# %%
out = pd.DataFrame()
out_list = list()

for i in range(len(OC_list)):
    x = df[OC_list[i]]
    
    for j in range(len(OC_list)):
        y = df[OC_list[j]]
        
        zipped = [ (a,b) for a,b in zip(x,y) if a is not np.nan and b is not np.nan]
        x =  [a for a,b in zipped]
        y =  [b for a,b in zipped]

        w,p = stats.wilcoxon(x=x,y=y)
        
        if p<0.05 and p>0.01:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))+'*'
        elif p<0.01:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))+'**'
        else:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(w,3))
        
        out_list.append([OC_list[j],OC_list[i],w,p])
        
out

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
out.to_csv('Wilcoxon_p.csv')
# Out:
# C:\Users\Mahdi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2882: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# C:\Users\Mahdi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2883: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# C:\Users\Mahdi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2865: RuntimeWarning: invalid value encountered in subtract
#   d = x - y
#                  Largest_Owner First_Second First_Sumtwofour   Sumfive  \
# Largest_Owner            0.0**        0.0**            0.0**    31.5**
# First_Second             0.0**        0.0**            0.0**     0.0**
# First_Sumtwofour         0.0**        0.0**            0.0**     0.0**
# Sumfive                 31.5**        0.0**            0.0**     0.0**
# Gini                     0.0**        0.0**           76.0**     0.0**
# Herfindhal               0.0**        0.0**            0.0**     0.0**
# SSCL                     0.0**        0.0**            0.0**     0.0**
# SSCO                  8970.0**     8970.0**         9014.0**  8970.0**
# SSDL                     0.0**        0.0**            0.0**     0.0**
# SSDO                     0.0**        0.0**           43.0**     0.0**
# BZCL                     0.0**        0.0**            0.0**     0.0**
# BZCO                     0.0**        0.0**           68.0**     0.0**
# BZDL                     0.0**        3.0**            3.0**     0.0**
#
#                        Gini Herfindhal       SSCL       SSCO       SSDL  \
# Largest_Owner         0.0**      0.0**      0.0**   8970.0**      0.0**
# First_Second          0.0**      0.0**      0.0**   8970.0**      0.0**
# First_Sumtwofour     76.0**      0.0**      0.0**   9014.0**      0.0**
# Sumfive               0.0**      0.0**      0.0**   8970.0**      0.0**
# Gini                  0.0**  34778.0**  55364.0**  16140.0**  50848.0**
# Herfindhal        34778.0**      0.0**     97.0**  48225.0**     93.0**
# SSCL              55364.0**     97.0**      0.0**  21593.0**   6195.0**
# SSCO              16140.0**  48225.0**  21593.0**      0.0**  20250.0**
# SSDL              50848.0**     93.0**   6195.0**  20250.0**      0.0**
# SSDO               7987.0**  38719.0**  12050.0**   8861.0**  11975.0**
# BZCL              38324.0**    149.0**   6146.0**  18215.0**   5920.0**
# BZCO               6760.0**  33179.0**  11036.0**   9017.0**   9993.0**
# BZDL              16406.0**     92.0**    408.0**  11533.0**    399.0**
#
#                        SSDO       BZCL       BZCO       BZDL
# Largest_Owner         0.0**      0.0**      0.0**      0.0**
# First_Second          0.0**      0.0**      0.0**      3.0**
# First_Sumtwofour     43.0**      0.0**     68.0**      3.0**
# Sumfive               0.0**      0.0**      0.0**      0.0**
# Gini               7987.0**  38324.0**   6760.0**  16406.0**
# Herfindhal        38719.0**    149.0**  33179.0**     92.0**
# SSCL              12050.0**   6146.0**  11036.0**    408.0**
# SSCO               8861.0**  18215.0**   9017.0**  11533.0**
# SSDL              11975.0**   5920.0**   9993.0**    399.0**
# SSDO                  0.0**   8789.0**   9894.0**   2201.0**
# BZCL               8789.0**      0.0**   8950.0**     60.0**
# BZCO               9894.0**   8950.0**      0.0**   3000.0**
# BZDL               2201.0**     60.0**   3000.0**      0.0**

# %% [markdown]
# ## Spearman Correlation Rank Test

# %%
out = pd.DataFrame()
out_list = list()

for i in range(len(OC_list)):
    x = df[OC_list[i]]
    
    for j in range(len(OC_list)):
        y = df[OC_list[j]]
        
        zipped = [ (a,b) for a,b in zip(x,y) if a is not np.nan and b is not np.nan]
        x =  [a for a,b in zipped]
        y =  [b for a,b in zipped]

        rho,p = stats.spearmanr(x,y,nan_policy='omit')
        if p<0.05 and p>0.01:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))+'*'
        elif p<0.01:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))+'**'
        else:
            out.loc[OC_list[j],OC_list[i]] = str(np.round(rho,4))
        
        out_list.append([OC_list[j],OC_list[i],w,p])
        
out

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
out.to_csv('Spearman_p.csv')
# Out:
#                  Largest_Owner First_Second First_Sumtwofour    Sumfive  \
# Largest_Owner            1.0**     0.5635**         0.6797**   0.5806**
# First_Second          0.5635**        1.0**         0.9356**     0.0305
# First_Sumtwofour      0.6797**     0.9356**            1.0**     0.0512
# Sumfive               0.5806**       0.0305           0.0512      1.0**
# Gini                  0.5556**     0.9131**         0.8869**     0.0713
# Herfindhal             0.976**     0.4516**         0.5792**   0.7015**
# SSCL                  0.8964**     0.5536**          0.677**   0.4806**
# SSCO                 -0.8586**    -0.4674**        -0.5495**    -0.58**
# SSDL                  0.8964**     0.5535**         0.6771**   0.4805**
# SSDO                 -0.8585**    -0.4684**        -0.5508**  -0.5774**
# BZCL                  0.8831**     0.5824**         0.7103**   0.4307**
# BZCO                 -0.8408**     -0.548**         -0.663**  -0.4581**
# BZDL                  0.6112**     0.4975**         0.6919**    0.1174*
#
#                        Gini Herfindhal       SSCL       SSCO       SSDL  \
# Largest_Owner      0.5556**    0.976**   0.8964**  -0.8586**   0.8964**
# First_Second       0.9131**   0.4516**   0.5536**  -0.4674**   0.5535**
# First_Sumtwofour   0.8869**   0.5792**    0.677**  -0.5495**   0.6771**
# Sumfive              0.0713   0.7015**   0.4806**    -0.58**   0.4805**
# Gini                  1.0**   0.4639**   0.5398**  -0.4612**   0.5397**
# Herfindhal         0.4639**      1.0**   0.8585**  -0.8494**   0.8585**
# SSCL               0.5398**   0.8585**      1.0**  -0.9435**      1.0**
# SSCO              -0.4612**  -0.8494**  -0.9435**      1.0**  -0.9432**
# SSDL               0.5397**   0.8585**      1.0**  -0.9432**      1.0**
# SSDO              -0.4621**  -0.8489**  -0.9439**   0.9996**  -0.9436**
# BZCL                0.562**   0.8355**   0.9888**  -0.9187**   0.9889**
# BZCO              -0.5385**  -0.8041**  -0.9398**   0.9226**  -0.9398**
# BZDL               0.4542**   0.5442**   0.7031**  -0.4959**   0.7038**
#
#                        SSDO       BZCL       BZCO       BZDL
# Largest_Owner     -0.8585**   0.8831**  -0.8408**   0.6112**
# First_Second      -0.4684**   0.5824**   -0.548**   0.4975**
# First_Sumtwofour  -0.5508**   0.7103**   -0.663**   0.6919**
# Sumfive           -0.5774**   0.4307**  -0.4581**    0.1174*
# Gini              -0.4621**    0.562**  -0.5385**   0.4542**
# Herfindhal        -0.8489**   0.8355**  -0.8041**   0.5442**
# SSCL              -0.9439**   0.9888**  -0.9398**   0.7031**
# SSCO               0.9996**  -0.9187**   0.9226**  -0.4959**
# SSDL              -0.9436**   0.9889**  -0.9398**   0.7038**
# SSDO                  1.0**  -0.9196**   0.9255**  -0.4956**
# BZCL              -0.9196**      1.0**  -0.9458**   0.7371**
# BZCO               0.9255**  -0.9458**      1.0**  -0.6405**
# BZDL              -0.4956**   0.7371**  -0.6405**      1.0**
