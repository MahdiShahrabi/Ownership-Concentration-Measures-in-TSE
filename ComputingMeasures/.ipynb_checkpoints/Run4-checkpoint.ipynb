# %%
from tell_time import tell_time
import pytz
from find_measures import find_measures

# %%
path = r"C:\Users\Mahdi\OneDrive\Master Thesis\Data\MonthlyShareholder"
os.chdir(path)
ls = os.listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ea22f6e06f42> in <module>
#       1 path = r"C:\Users\Mahdi\OneDrive\Master Thesis\Data\MonthlyShareholder"
# ----> 2 os.chdir(path)
#       3 ls = os.listdir()
#
# NameError: name 'os' is not defined

# %%
for year in range(1388,1389):
    
    for month in range(1,2):
        
        tell_time('**Year '+str(year)+'|'+str(month)+' has Started!***')
        print('\n')
        
        if "Measures"+str(year)+'_'+str(month)+".csv" not in ls:            
            try:                
                find_measures(year=year,month=month,pnt=True)
                print('\n\n')                    
            except:
                pass
# Out:
# **Year 1388|1 has Started!***
# Current time is:  18:48:21
# Number of observed firms in year  1388  is :  238
# C:\Users\Mahdi\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\Mahdi\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# NEW!
# The symbol  آکنتور  mode:  SSCL ,  1  from  952
#  It took about  0.9 seconds
# The symbol  آکنتور  mode:  SSDL ,  2  from  952
#  It took about  0.71 seconds
# The symbol  آکنتور  mode:  BZCL ,  3  from  952
# It took about  0.85 seconds
# The symbol  آکنتور  mode:  BZDL ,  4  from  952
# The symbol  بالبر  mode:  SSCL ,  5  from  952
#  It took about  0.71 seconds
# The symbol  بالبر  mode:  SSDL ,  6  from  952
#  It took about  0.72 seconds
# The symbol  بالبر  mode:  BZCL ,  7  from  952
# It took about  0.83 seconds
# The symbol  بالبر  mode:  BZDL ,  8  from  952
# It took about  0.76 seconds
# The symbol  بترانس  mode:  SSCL ,  9  from  952
#  It took about  0.71 seconds
# The symbol  بترانس  mode:  SSDL ,  10  from  952
#  It took about  0.77 seconds
# The symbol  بترانس  mode:  BZCL ,  11  from  952
# It took about  0.91 seconds
# The symbol  بترانس  mode:  BZDL ,  12  from  952
# The symbol  بسویچ  mode:  SSCL ,  13  from  952
#  It took about  0.82 seconds
# The symbol  بسویچ  mode:  SSDL ,  14  from  952
#  It took about  0.07 seconds
# The symbol  بسویچ  mode:  BZCL ,  15  from  952
# It took about  0.22 seconds
# The symbol  بسویچ  mode:  BZDL ,  16  from  952
# It took about  0.0 seconds
# The symbol  بشهاب  mode:  SSCL ,  17  from  952
#  It took about  0.85 seconds
# The symbol  بشهاب  mode:  SSDL ,  18  from  952
#  It took about  0.86 seconds
# The symbol  بشهاب  mode:  BZCL ,  19  from  952
# It took about  0.85 seconds
# The symbol  بشهاب  mode:  BZDL ,  20  from  952
# It took about  0.7 seconds
# The symbol  بموتو  mode:  SSCL ,  21  from  952
#  It took about  0.89 seconds
# The symbol  بموتو  mode:  SSDL ,  22  from  952
#  It took about  0.86 seconds
# The symbol  بموتو  mode:  BZCL ,  23  from  952
# It took about  0.7 seconds
# The symbol  بموتو  mode:  BZDL ,  24  from  952
# It took about  0.72 seconds
# The symbol  بنیرو  mode:  SSCL ,  25  from  952
#  It took about  0.85 seconds
# The symbol  بنیرو  mode:  SSDL ,  26  from  952
#  It took about  0.76 seconds
# The symbol  بنیرو  mode:  BZCL ,  27  from  952
# It took about  0.9 seconds
# The symbol  بنیرو  mode:  BZDL ,  28  from  952
# It took about  0.7 seconds
# The symbol  بکاب  mode:  SSCL ,  29  from  952
#  It took about  1.0 seconds
# The symbol  بکاب  mode:  SSDL ,  30  from  952
#  It took about  0.7 seconds
# The symbol  بکاب  mode:  BZCL ,  31  from  952
# It took about  0.84 seconds
# The symbol  بکاب  mode:  BZDL ,  32  from  952
# The symbol  بکام  mode:  SSCL ,  33  from  952
# The symbol  بکام  mode:  SSDL ,  34  from  952
# The symbol  بکام  mode:  BZCL ,  35  from  952
# The symbol  بکام  mode:  BZDL ,  36  from  952
# The symbol  تایرا  mode:  SSCL ,  37  from  952
#  It took about  0.7 seconds
# The symbol  تایرا  mode:  SSDL ,  38  from  952
#  It took about  0.7 seconds
# The symbol  تایرا  mode:  BZCL ,  39  from  952
# It took about  0.7 seconds
# The symbol  تایرا  mode:  BZDL ,  40  from  952
# It took about  0.78 seconds
# The symbol  تمحرکه  mode:  SSCL ,  41  from  952
#  It took about  0.7 seconds
# The symbol  تمحرکه  mode:  SSDL ,  42  from  952
#  It took about  0.87 seconds
# The symbol  تمحرکه  mode:  BZCL ,  43  from  952
# It took about  0.8 seconds
# The symbol  تمحرکه  mode:  BZDL ,  44  from  952
# The symbol  تپمپی  mode:  SSCL ,  45  from  952
#  It took about  0.86 seconds
# The symbol  تپمپی  mode:  SSDL ,  46  from  952
#  It took about  0.7 seconds
# The symbol  تپمپی  mode:  BZCL ,  47  from  952
# It took about  0.7 seconds
# The symbol  تپمپی  mode:  BZDL ,  48  from  952
# It took about  0.81 seconds
# The symbol  تکشا  mode:  SSCL ,  49  from  952
#  It took about  0.77 seconds
# The symbol  تکشا  mode:  SSDL ,  50  from  952
#  It took about  0.9 seconds
# The symbol  تکشا  mode:  BZCL ,  51  from  952
# It took about  0.86 seconds
# The symbol  تکشا  mode:  BZDL ,  52  from  952
# The symbol  تکمبا  mode:  SSCL ,  53  from  952
#  It took about  0.7 seconds
# The symbol  تکمبا  mode:  SSDL ,  54  from  952
#  It took about  0.82 seconds
# The symbol  تکمبا  mode:  BZCL ,  55  from  952
# It took about  0.78 seconds
# The symbol  تکمبا  mode:  BZDL ,  56  from  952
# It took about  0.78 seconds
# The symbol  تکنو  mode:  SSCL ,  57  from  952
#  It took about  0.83 seconds
# The symbol  تکنو  mode:  SSDL ,  58  from  952
#  It took about  0.71 seconds
# The symbol  تکنو  mode:  BZCL ,  59  from  952
# It took about  0.82 seconds
# The symbol  تکنو  mode:  BZDL ,  60  from  952
# It took about  0.7 seconds
# The symbol  ثاباد  mode:  SSCL ,  61  from  952
# The symbol  ثاباد  mode:  SSDL ,  62  from  952
# The symbol  ثاباد  mode:  BZCL ,  63  from  952
# The symbol  ثاباد  mode:  BZDL ,  64  from  952
# The symbol  ثاخت  mode:  SSCL ,  65  from  952
#  It took about  0.82 seconds
# The symbol  ثاخت  mode:  SSDL ,  66  from  952
#  It took about  0.85 seconds
# The symbol  ثاخت  mode:  BZCL ,  67  from  952
# It took about  0.82 seconds
# The symbol  ثاخت  mode:  BZDL ,  68  from  952
# The symbol  ثامان  mode:  SSCL ,  69  from  952
#  It took about  0.28 seconds
# The symbol  ثامان  mode:  SSDL ,  70  from  952
#  It took about  0.71 seconds
# The symbol  ثامان  mode:  BZCL ,  71  from  952
# It took about  0.88 seconds
# The symbol  ثامان  mode:  BZDL ,  72  from  952
# The symbol  ثاژن  mode:  SSCL ,  73  from  952
#  It took about  0.85 seconds
# The symbol  ثاژن  mode:  SSDL ,  74  from  952
#  It took about  0.91 seconds
# The symbol  ثاژن  mode:  BZCL ,  75  from  952
# It took about  0.9 seconds
# The symbol  ثاژن  mode:  BZDL ,  76  from  952
# The symbol  ثشاهد  mode:  SSCL ,  77  from  952
# The symbol  ثشاهد  mode:  SSDL ,  78  from  952
# The symbol  ثشاهد  mode:  BZCL ,  79  from  952
# The symbol  ثشاهد  mode:  BZDL ,  80  from  952
# The symbol  ثفارس  mode:  SSCL ,  81  from  952
#  It took about  0.81 seconds
# The symbol  ثفارس  mode:  SSDL ,  82  from  952
#  It took about  0.72 seconds
# The symbol  ثفارس  mode:  BZCL ,  83  from  952
# It took about  0.7 seconds
# The symbol  ثفارس  mode:  BZDL ,  84  from  952
# It took about  0.94 seconds
# The symbol  ثمسکن  mode:  SSCL ,  85  from  952
# The symbol  ثمسکن  mode:  SSDL ,  86  from  952
# The symbol  ثمسکن  mode:  BZCL ,  87  from  952
# The symbol  ثمسکن  mode:  BZDL ,  88  from  952
# The symbol  ثنوسا  mode:  SSCL ,  89  from  952
#  It took about  0.85 seconds
# The symbol  ثنوسا  mode:  SSDL ,  90  from  952
#  It took about  0.7 seconds
# The symbol  ثنوسا  mode:  BZCL ,  91  from  952
# It took about  0.8 seconds
# The symbol  ثنوسا  mode:  BZDL ,  92  from  952
# It took about  0.71 seconds
# The symbol  حتاید  mode:  SSCL ,  93  from  952
# The symbol  حتاید  mode:  SSDL ,  94  from  952
# The symbol  حتاید  mode:  BZCL ,  95  from  952
# The symbol  حتاید  mode:  BZDL ,  96  from  952
# The symbol  حتوکا  mode:  SSCL ,  97  from  952
#  It took about  0.87 seconds
# The symbol  حتوکا  mode:  SSDL ,  98  from  952
#  It took about  0.82 seconds
# The symbol  حتوکا  mode:  BZCL ,  99  from  952
# It took about  0.71 seconds
# The symbol  حتوکا  mode:  BZDL ,  100  from  952
# The symbol  حکشتی  mode:  SSCL ,  101  from  952
#  It took about  0.85 seconds
# The symbol  حکشتی  mode:  SSDL ,  102  from  952
#  It took about  0.7 seconds
# The symbol  حکشتی  mode:  BZCL ,  103  from  952
# It took about  0.7 seconds
# The symbol  حکشتی  mode:  BZDL ,  104  from  952
# It took about  0.72 seconds
# The symbol  خاذین  mode:  SSCL ,  105  from  952
# The symbol  خاذین  mode:  SSDL ,  106  from  952
# The symbol  خاذین  mode:  BZCL ,  107  from  952
# The symbol  خاذین  mode:  BZDL ,  108  from  952
# The symbol  خاهن  mode:  SSCL ,  109  from  952
#  It took about  0.82 seconds
# The symbol  خاهن  mode:  SSDL ,  110  from  952
#  It took about  0.72 seconds
# The symbol  خاهن  mode:  BZCL ,  111  from  952
# It took about  0.88 seconds
# The symbol  خاهن  mode:  BZDL ,  112  from  952
# It took about  0.98 seconds
# The symbol  خبهمن  mode:  SSCL ,  113  from  952
#  It took about  0.71 seconds
# The symbol  خبهمن  mode:  SSDL ,  114  from  952
#  It took about  0.9 seconds
# The symbol  خبهمن  mode:  BZCL ,  115  from  952
# It took about  0.85 seconds
# The symbol  خبهمن  mode:  BZDL ,  116  from  952
# It took about  0.77 seconds
# The symbol  ختراک  mode:  SSCL ,  117  from  952
#  It took about  0.9 seconds
# The symbol  ختراک  mode:  SSDL ,  118  from  952
#  It took about  0.02 seconds
# The symbol  ختراک  mode:  BZCL ,  119  from  952
# It took about  0.8 seconds
# The symbol  ختراک  mode:  BZDL ,  120  from  952
# The symbol  ختور  mode:  SSCL ,  121  from  952
#  It took about  0.87 seconds
# The symbol  ختور  mode:  SSDL ,  122  from  952
#  It took about  0.72 seconds
# The symbol  ختور  mode:  BZCL ,  123  from  952
# It took about  0.73 seconds
# The symbol  ختور  mode:  BZDL ,  124  from  952
# It took about  0.76 seconds
# The symbol  ختوقا  mode:  SSCL ,  125  from  952
#  It took about  0.79 seconds
# The symbol  ختوقا  mode:  SSDL ,  126  from  952
#  It took about  0.71 seconds
# The symbol  ختوقا  mode:  BZCL ,  127  from  952
# It took about  0.71 seconds
# The symbol  ختوقا  mode:  BZDL ,  128  from  952
# It took about  0.7 seconds
# The symbol  خریخت  mode:  SSCL ,  129  from  952
#  It took about  0.82 seconds
# The symbol  خریخت  mode:  SSDL ,  130  from  952
#  It took about  0.72 seconds
# The symbol  خریخت  mode:  BZCL ,  131  from  952
# It took about  0.71 seconds
# The symbol  خریخت  mode:  BZDL ,  132  from  952
# It took about  0.82 seconds
# The symbol  خرینگ  mode:  SSCL ,  133  from  952
#  It took about  0.7 seconds
# The symbol  خرینگ  mode:  SSDL ,  134  from  952
#  It took about  0.97 seconds
# The symbol  خرینگ  mode:  BZCL ,  135  from  952
# It took about  0.72 seconds
# The symbol  خرینگ  mode:  BZDL ,  136  from  952
# The symbol  خزامیا  mode:  SSCL ,  137  from  952
#  It took about  0.82 seconds
# The symbol  خزامیا  mode:  SSDL ,  138  from  952
#  It took about  0.94 seconds
# The symbol  خزامیا  mode:  BZCL ,  139  from  952
# It took about  0.81 seconds
# The symbol  خزامیا  mode:  BZDL ,  140  from  952
# The symbol  خزر  mode:  SSCL ,  141  from  952
#  It took about  0.79 seconds
# The symbol  خزر  mode:  SSDL ,  142  from  952
#  It took about  0.72 seconds
# The symbol  خزر  mode:  BZCL ,  143  from  952
# It took about  0.73 seconds
# The symbol  خزر  mode:  BZDL ,  144  from  952
# It took about  0.81 seconds
# The symbol  خساپا  mode:  SSCL ,  145  from  952
#  It took about  0.84 seconds
# The symbol  خساپا  mode:  SSDL ,  146  from  952
#  It took about  0.7 seconds
# The symbol  خساپا  mode:  BZCL ,  147  from  952
# It took about  1.0 seconds
# The symbol  خساپا  mode:  BZDL ,  148  from  952
# It took about  0.7 seconds
# The symbol  خشرق  mode:  SSCL ,  149  from  952
# The symbol  خشرق  mode:  SSDL ,  150  from  952
# The symbol  خشرق  mode:  BZCL ,  151  from  952
# The symbol  خشرق  mode:  BZDL ,  152  from  952
# The symbol  خفنر  mode:  SSCL ,  153  from  952
# The symbol  خفنر  mode:  SSDL ,  154  from  952
# The symbol  خفنر  mode:  BZCL ,  155  from  952
# The symbol  خفنر  mode:  BZDL ,  156  from  952
# The symbol  خلنت  mode:  SSCL ,  157  from  952
#  It took about  0.84 seconds
# The symbol  خلنت  mode:  SSDL ,  158  from  952
#  It took about  0.75 seconds
# The symbol  خلنت  mode:  BZCL ,  159  from  952
# It took about  0.95 seconds
# The symbol  خلنت  mode:  BZDL ,  160  from  952
# The symbol  خمحرکه  mode:  SSCL ,  161  from  952
#  It took about  0.84 seconds
# The symbol  خمحرکه  mode:  SSDL ,  162  from  952
#  It took about  0.73 seconds
# The symbol  خمحرکه  mode:  BZCL ,  163  from  952
# It took about  0.73 seconds
# The symbol  خمحرکه  mode:  BZDL ,  164  from  952
# The symbol  خمحور  mode:  SSCL ,  165  from  952
#  It took about  0.84 seconds
# The symbol  خمحور  mode:  SSDL ,  166  from  952
#  It took about  0.97 seconds
# The symbol  خمحور  mode:  BZCL ,  167  from  952
# It took about  0.95 seconds
# The symbol  خمحور  mode:  BZDL ,  168  from  952
# The symbol  خمهر  mode:  SSCL ,  169  from  952
#  It took about  0.85 seconds
# The symbol  خمهر  mode:  SSDL ,  170  from  952
#  It took about  0.03 seconds
# The symbol  خمهر  mode:  BZCL ,  171  from  952
# It took about  0.76 seconds
# The symbol  خمهر  mode:  BZDL ,  172  from  952
# It took about  0.77 seconds
# The symbol  خموتور  mode:  SSCL ,  173  from  952
#  It took about  0.72 seconds
# The symbol  خموتور  mode:  SSDL ,  174  from  952
#  It took about  0.86 seconds
# The symbol  خموتور  mode:  BZCL ,  175  from  952
# It took about  0.7 seconds
# The symbol  خموتور  mode:  BZDL ,  176  from  952
# The symbol  خنصیر  mode:  SSCL ,  177  from  952
#  It took about  0.71 seconds
# The symbol  خنصیر  mode:  SSDL ,  178  from  952
#  It took about  0.72 seconds
# The symbol  خنصیر  mode:  BZCL ,  179  from  952
# It took about  0.81 seconds
# The symbol  خنصیر  mode:  BZDL ,  180  from  952
# The symbol  خودرو  mode:  SSCL ,  181  from  952
#  It took about  0.71 seconds
# The symbol  خودرو  mode:  SSDL ,  182  from  952
#  It took about  0.72 seconds
# The symbol  خودرو  mode:  BZCL ,  183  from  952
# It took about  0.82 seconds
# The symbol  خودرو  mode:  BZDL ,  184  from  952
# It took about  0.73 seconds
# The symbol  خوساز  mode:  SSCL ,  185  from  952
#  It took about  0.9 seconds
# The symbol  خوساز  mode:  SSDL ,  186  from  952
#  It took about  0.87 seconds
# The symbol  خوساز  mode:  BZCL ,  187  from  952
# It took about  0.86 seconds
# The symbol  خوساز  mode:  BZDL ,  188  from  952
# The symbol  خپارس  mode:  SSCL ,  189  from  952
#  It took about  0.78 seconds
# The symbol  خپارس  mode:  SSDL ,  190  from  952
#  It took about  0.93 seconds
# The symbol  خپارس  mode:  BZCL ,  191  from  952
# It took about  0.91 seconds
# The symbol  خپارس  mode:  BZDL ,  192  from  952
# The symbol  خپویش  mode:  SSCL ,  193  from  952
# The symbol  خپویش  mode:  SSDL ,  194  from  952
# The symbol  خپویش  mode:  BZCL ,  195  from  952
# The symbol  خپویش  mode:  BZDL ,  196  from  952
# The symbol  خچرخش  mode:  SSCL ,  197  from  952
#  It took about  0.92 seconds
# The symbol  خچرخش  mode:  SSDL ,  198  from  952
#  It took about  0.7 seconds
# The symbol  خچرخش  mode:  BZCL ,  199  from  952
# It took about  0.82 seconds
# The symbol  خچرخش  mode:  BZDL ,  200  from  952
# It took about  0.9 seconds
# The symbol  خکار  mode:  SSCL ,  201  from  952
#  It took about  0.95 seconds
# The symbol  خکار  mode:  SSDL ,  202  from  952
#  It took about  0.78 seconds
# The symbol  خکار  mode:  BZCL ,  203  from  952
# It took about  0.84 seconds
# The symbol  خکار  mode:  BZDL ,  204  from  952
# The symbol  خکمک  mode:  SSCL ,  205  from  952
#  It took about  0.91 seconds
# The symbol  خکمک  mode:  SSDL ,  206  from  952
#  It took about  0.71 seconds
# The symbol  خکمک  mode:  BZCL ,  207  from  952
# It took about  0.71 seconds
# The symbol  خکمک  mode:  BZDL ,  208  from  952
# The symbol  خگستر  mode:  SSCL ,  209  from  952
#  It took about  0.8 seconds
# The symbol  خگستر  mode:  SSDL ,  210  from  952
#  It took about  0.85 seconds
# The symbol  خگستر  mode:  BZCL ,  211  from  952
# It took about  0.73 seconds
# The symbol  خگستر  mode:  BZDL ,  212  from  952
# The symbol  دارو  mode:  SSCL ,  213  from  952
# The symbol  دارو  mode:  SSDL ,  214  from  952
# The symbol  دارو  mode:  BZCL ,  215  from  952
# The symbol  دارو  mode:  BZDL ,  216  from  952
# The symbol  داسوه  mode:  SSCL ,  217  from  952
# The symbol  داسوه  mode:  SSDL ,  218  from  952
# The symbol  داسوه  mode:  BZCL ,  219  from  952
# The symbol  داسوه  mode:  BZDL ,  220  from  952
# The symbol  دالبر  mode:  SSCL ,  221  from  952
#  It took about  0.83 seconds
# The symbol  دالبر  mode:  SSDL ,  222  from  952
#  It took about  0.87 seconds
# The symbol  دالبر  mode:  BZCL ,  223  from  952
# It took about  0.8 seconds
# The symbol  دالبر  mode:  BZDL ,  224  from  952
# It took about  0.96 seconds
# The symbol  دامین  mode:  SSCL ,  225  from  952
#  It took about  0.76 seconds
# The symbol  دامین  mode:  SSDL ,  226  from  952
#  It took about  0.73 seconds
# The symbol  دامین  mode:  BZCL ,  227  from  952
# It took about  0.77 seconds
# The symbol  دامین  mode:  BZDL ,  228  from  952
# The symbol  دتماد  mode:  SSCL ,  229  from  952
# The symbol  دتماد  mode:  SSDL ,  230  from  952
# The symbol  دتماد  mode:  BZCL ,  231  from  952
# The symbol  دتماد  mode:  BZDL ,  232  from  952
# The symbol  دجابر  mode:  SSCL ,  233  from  952
#  It took about  0.86 seconds
# The symbol  دجابر  mode:  SSDL ,  234  from  952
#  It took about  0.72 seconds
# The symbol  دجابر  mode:  BZCL ,  235  from  952
# It took about  0.88 seconds
# The symbol  دجابر  mode:  BZDL ,  236  from  952
# The symbol  ددام  mode:  SSCL ,  237  from  952
# The symbol  ددام  mode:  SSDL ,  238  from  952
# The symbol  ددام  mode:  BZCL ,  239  from  952
# The symbol  ددام  mode:  BZDL ,  240  from  952
# The symbol  دزهراوی  mode:  SSCL ,  241  from  952
#  It took about  0.77 seconds
# The symbol  دزهراوی  mode:  SSDL ,  242  from  952
#  It took about  0.88 seconds
# The symbol  دزهراوی  mode:  BZCL ,  243  from  952
# It took about  0.03 seconds
# The symbol  دزهراوی  mode:  BZDL ,  244  from  952
# It took about  0.72 seconds
# The symbol  دسبحا  mode:  SSCL ,  245  from  952
# The symbol  دسبحا  mode:  SSDL ,  246  from  952
# The symbol  دسبحا  mode:  BZCL ,  247  from  952
# The symbol  دسبحا  mode:  BZDL ,  248  from  952
# The symbol  دسینا  mode:  SSCL ,  249  from  952
#  It took about  0.83 seconds
# The symbol  دسینا  mode:  SSDL ,  250  from  952
#  It took about  0.73 seconds
# The symbol  دسینا  mode:  BZCL ,  251  from  952
# It took about  0.73 seconds
# The symbol  دسینا  mode:  BZDL ,  252  from  952
# The symbol  دشیمی  mode:  SSCL ,  253  from  952
# The symbol  دشیمی  mode:  SSDL ,  254  from  952
# The symbol  دشیمی  mode:  BZCL ,  255  from  952
# The symbol  دشیمی  mode:  BZDL ,  256  from  952
# The symbol  دعبید  mode:  SSCL ,  257  from  952
#  It took about  0.71 seconds
# The symbol  دعبید  mode:  SSDL ,  258  from  952
#  It took about  0.83 seconds
# The symbol  دعبید  mode:  BZCL ,  259  from  952
# It took about  0.72 seconds
# The symbol  دعبید  mode:  BZDL ,  260  from  952
# The symbol  دفارا  mode:  SSCL ,  261  from  952
# The symbol  دفارا  mode:  SSDL ,  262  from  952
# The symbol  دفارا  mode:  BZCL ,  263  from  952
# The symbol  دفارا  mode:  BZDL ,  264  from  952
# The symbol  دفرا  mode:  SSCL ,  265  from  952
#  It took about  0.83 seconds
# The symbol  دفرا  mode:  SSDL ,  266  from  952
#  It took about  0.78 seconds
# The symbol  دفرا  mode:  BZCL ,  267  from  952
# It took about  0.75 seconds
# The symbol  دفرا  mode:  BZDL ,  268  from  952
# It took about  0.89 seconds
# The symbol  دلر  mode:  SSCL ,  269  from  952
# The symbol  دلر  mode:  SSDL ,  270  from  952
# The symbol  دلر  mode:  BZCL ,  271  from  952
# The symbol  دلر  mode:  BZDL ,  272  from  952
# The symbol  دلقما  mode:  SSCL ,  273  from  952
# The symbol  دلقما  mode:  SSDL ,  274  from  952
# The symbol  دلقما  mode:  BZCL ,  275  from  952
# The symbol  دلقما  mode:  BZDL ,  276  from  952
# The symbol  دپارس  mode:  SSCL ,  277  from  952
# The symbol  دپارس  mode:  SSDL ,  278  from  952
# The symbol  دپارس  mode:  BZCL ,  279  from  952
# The symbol  دپارس  mode:  BZDL ,  280  from  952
# The symbol  دکوثر  mode:  SSCL ,  281  from  952
#  It took about  0.73 seconds
# The symbol  دکوثر  mode:  SSDL ,  282  from  952
#  It took about  0.91 seconds
# The symbol  دکوثر  mode:  BZCL ,  283  from  952
# It took about  0.88 seconds
# The symbol  دکوثر  mode:  BZDL ,  284  from  952
# The symbol  دکیمی  mode:  SSCL ,  285  from  952
#  It took about  0.74 seconds
# The symbol  دکیمی  mode:  SSDL ,  286  from  952
#  It took about  0.73 seconds
# The symbol  دکیمی  mode:  BZCL ,  287  from  952
# It took about  0.05 seconds
# The symbol  دکیمی  mode:  BZDL ,  288  from  952
# The symbol  دیران  mode:  SSCL ,  289  from  952
# The symbol  دیران  mode:  SSDL ,  290  from  952
# The symbol  دیران  mode:  BZCL ,  291  from  952
# The symbol  دیران  mode:  BZDL ,  292  from  952
# The symbol  رانفور  mode:  SSCL ,  293  from  952
# The symbol  رانفور  mode:  SSDL ,  294  from  952
# The symbol  رانفور  mode:  BZCL ,  295  from  952
# The symbol  رانفور  mode:  BZDL ,  296  from  952
# The symbol  رتکو  mode:  SSCL ,  297  from  952
# The symbol  رتکو  mode:  SSDL ,  298  from  952
# The symbol  رتکو  mode:  BZCL ,  299  from  952
# The symbol  رتکو  mode:  BZDL ,  300  from  952
# The symbol  رمپنا  mode:  SSCL ,  301  from  952
#  It took about  0.71 seconds
# The symbol  رمپنا  mode:  SSDL ,  302  from  952
#  It took about  0.7 seconds
# The symbol  رمپنا  mode:  BZCL ,  303  from  952
# It took about  0.91 seconds
# The symbol  رمپنا  mode:  BZDL ,  304  from  952
# The symbol  ساراب  mode:  SSCL ,  305  from  952
#  It took about  0.71 seconds
# The symbol  ساراب  mode:  SSDL ,  306  from  952
#  It took about  0.73 seconds
# The symbol  ساراب  mode:  BZCL ,  307  from  952
# It took about  0.71 seconds
# The symbol  ساراب  mode:  BZDL ,  308  from  952
# The symbol  ساربیل  mode:  SSCL ,  309  from  952
#  It took about  0.84 seconds
# The symbol  ساربیل  mode:  SSDL ,  310  from  952
#  It took about  0.8 seconds
# The symbol  ساربیل  mode:  BZCL ,  311  from  952
# It took about  0.92 seconds
# The symbol  ساربیل  mode:  BZDL ,  312  from  952
# The symbol  ساروم  mode:  SSCL ,  313  from  952
# The symbol  ساروم  mode:  SSDL ,  314  from  952
# The symbol  ساروم  mode:  BZCL ,  315  from  952
# The symbol  ساروم  mode:  BZDL ,  316  from  952
# The symbol  سبجنو  mode:  SSCL ,  317  from  952
#  It took about  0.72 seconds
# The symbol  سبجنو  mode:  SSDL ,  318  from  952
#  It took about  0.84 seconds
# The symbol  سبجنو  mode:  BZCL ,  319  from  952
# It took about  0.71 seconds
# The symbol  سبجنو  mode:  BZDL ,  320  from  952
# The symbol  سبهان  mode:  SSCL ,  321  from  952
#  It took about  0.78 seconds
# The symbol  سبهان  mode:  SSDL ,  322  from  952
#  It took about  0.72 seconds
# The symbol  سبهان  mode:  BZCL ,  323  from  952
# It took about  0.86 seconds
# The symbol  سبهان  mode:  BZDL ,  324  from  952
# The symbol  ستران  mode:  SSCL ,  325  from  952
#  It took about  0.73 seconds
# The symbol  ستران  mode:  SSDL ,  326  from  952
#  It took about  0.94 seconds
# The symbol  ستران  mode:  BZCL ,  327  from  952
# It took about  0.76 seconds
# The symbol  ستران  mode:  BZDL ,  328  from  952
# It took about  0.86 seconds
# The symbol  سخاش  mode:  SSCL ,  329  from  952
#  It took about  0.75 seconds
# The symbol  سخاش  mode:  SSDL ,  330  from  952
#  It took about  0.88 seconds
# The symbol  سخاش  mode:  BZCL ,  331  from  952
# It took about  0.72 seconds
# The symbol  سخاش  mode:  BZDL ,  332  from  952
# It took about  0.98 seconds
# The symbol  سخزر  mode:  SSCL ,  333  from  952
#  It took about  0.93 seconds
# The symbol  سخزر  mode:  SSDL ,  334  from  952
#  It took about  0.83 seconds
# The symbol  سخزر  mode:  BZCL ,  335  from  952
# It took about  0.79 seconds
# The symbol  سخزر  mode:  BZDL ,  336  from  952
# It took about  0.76 seconds
# The symbol  سدشت  mode:  SSCL ,  337  from  952
#  It took about  0.71 seconds
# The symbol  سدشت  mode:  SSDL ,  338  from  952
#  It took about  0.87 seconds
# The symbol  سدشت  mode:  BZCL ,  339  from  952
# It took about  0.83 seconds
# The symbol  سدشت  mode:  BZDL ,  340  from  952
# It took about  0.71 seconds
# The symbol  سدور  mode:  SSCL ,  341  from  952
#  It took about  0.85 seconds
# The symbol  سدور  mode:  SSDL ,  342  from  952
#  It took about  0.72 seconds
# The symbol  سدور  mode:  BZCL ,  343  from  952
# It took about  0.84 seconds
# The symbol  سدور  mode:  BZDL ,  344  from  952
# It took about  0.14 seconds
# The symbol  سرود  mode:  SSCL ,  345  from  952
#  It took about  0.74 seconds
# The symbol  سرود  mode:  SSDL ,  346  from  952
#  It took about  0.02 seconds
# The symbol  سرود  mode:  BZCL ,  347  from  952
# It took about  0.71 seconds
# The symbol  سرود  mode:  BZDL ,  348  from  952
# The symbol  سشرق  mode:  SSCL ,  349  from  952
#  It took about  0.86 seconds
# The symbol  سشرق  mode:  SSDL ,  350  from  952
#  It took about  0.82 seconds
# The symbol  سشرق  mode:  BZCL ,  351  from  952
# It took about  0.03 seconds
# The symbol  سشرق  mode:  BZDL ,  352  from  952
# It took about  0.71 seconds
# The symbol  سشمال  mode:  SSCL ,  353  from  952
#  It took about  0.86 seconds
# The symbol  سشمال  mode:  SSDL ,  354  from  952
#  It took about  0.79 seconds
# The symbol  سشمال  mode:  BZCL ,  355  from  952
# It took about  0.75 seconds
# The symbol  سشمال  mode:  BZDL ,  356  from  952
# The symbol  سصوفی  mode:  SSCL ,  357  from  952
# The symbol  سصوفی  mode:  SSDL ,  358  from  952
# The symbol  سصوفی  mode:  BZCL ,  359  from  952
# The symbol  سصوفی  mode:  BZDL ,  360  from  952
# The symbol  سغرب  mode:  SSCL ,  361  from  952
#  It took about  0.91 seconds
# The symbol  سغرب  mode:  SSDL ,  362  from  952
#  It took about  0.89 seconds
# The symbol  سغرب  mode:  BZCL ,  363  from  952
# It took about  0.72 seconds
# The symbol  سغرب  mode:  BZDL ,  364  from  952
# It took about  0.88 seconds
# The symbol  سفار  mode:  SSCL ,  365  from  952
#  It took about  0.71 seconds
# The symbol  سفار  mode:  SSDL ,  366  from  952
#  It took about  0.08 seconds
# The symbol  سفار  mode:  BZCL ,  367  from  952
# It took about  0.7 seconds
# The symbol  سفار  mode:  BZDL ,  368  from  952
# It took about  0.87 seconds
# The symbol  سفارس  mode:  SSCL ,  369  from  952
#  It took about  0.72 seconds
# The symbol  سفارس  mode:  SSDL ,  370  from  952
#  It took about  0.88 seconds
# The symbol  سفارس  mode:  BZCL ,  371  from  952
# It took about  0.73 seconds
# The symbol  سفارس  mode:  BZDL ,  372  from  952
# The symbol  سقاین  mode:  SSCL ,  373  from  952
#  It took about  0.72 seconds
# The symbol  سقاین  mode:  SSDL ,  374  from  952
#  It took about  0.9 seconds
# The symbol  سقاین  mode:  BZCL ,  375  from  952
# It took about  0.76 seconds
# The symbol  سقاین  mode:  BZDL ,  376  from  952
# The symbol  سمازن  mode:  SSCL ,  377  from  952
#  It took about  0.83 seconds
# The symbol  سمازن  mode:  SSDL ,  378  from  952
#  It took about  0.83 seconds
# The symbol  سمازن  mode:  BZCL ,  379  from  952
# It took about  0.91 seconds
# The symbol  سمازن  mode:  BZDL ,  380  from  952
# It took about  0.72 seconds
# The symbol  سنیر  mode:  SSCL ,  381  from  952
# The symbol  سنیر  mode:  SSDL ,  382  from  952
# The symbol  سنیر  mode:  BZCL ,  383  from  952
# The symbol  سنیر  mode:  BZDL ,  384  from  952
# The symbol  سهرمز  mode:  SSCL ,  385  from  952
# The symbol  سهرمز  mode:  SSDL ,  386  from  952
# The symbol  سهرمز  mode:  BZCL ,  387  from  952
# The symbol  سهرمز  mode:  BZDL ,  388  from  952
# The symbol  سهگمت  mode:  SSCL ,  389  from  952
# The symbol  سهگمت  mode:  SSDL ,  390  from  952
# The symbol  سهگمت  mode:  BZCL ,  391  from  952
# The symbol  سهگمت  mode:  BZDL ,  392  from  952
# The symbol  سپاها  mode:  SSCL ,  393  from  952
#  It took about  0.73 seconds
# The symbol  سپاها  mode:  SSDL ,  394  from  952
#  It took about  0.72 seconds
# The symbol  سپاها  mode:  BZCL ,  395  from  952
# It took about  0.85 seconds
# The symbol  سپاها  mode:  BZDL ,  396  from  952
# It took about  0.76 seconds
# The symbol  سکرد  mode:  SSCL ,  397  from  952
# The symbol  سکرد  mode:  SSDL ,  398  from  952
# The symbol  سکرد  mode:  BZCL ,  399  from  952
# The symbol  سکرد  mode:  BZDL ,  400  from  952
# The symbol  سکرما  mode:  SSCL ,  401  from  952
#  It took about  0.84 seconds
# The symbol  سکرما  mode:  SSDL ,  402  from  952
#  It took about  0.7 seconds
# The symbol  سکرما  mode:  BZCL ,  403  from  952
# It took about  0.83 seconds
# The symbol  سکرما  mode:  BZDL ,  404  from  952
# The symbol  سیلام  mode:  SSCL ,  405  from  952
#  It took about  0.71 seconds
# The symbol  سیلام  mode:  SSDL ,  406  from  952
#  It took about  0.94 seconds
# The symbol  سیلام  mode:  BZCL ,  407  from  952
# It took about  0.73 seconds
# The symbol  سیلام  mode:  BZDL ,  408  from  952
# It took about  0.84 seconds
# The symbol  شاراک  mode:  SSCL ,  409  from  952
#  It took about  0.74 seconds
# The symbol  شاراک  mode:  SSDL ,  410  from  952
#  It took about  0.72 seconds
# The symbol  شاراک  mode:  BZCL ,  411  from  952
# It took about  0.72 seconds
# The symbol  شاراک  mode:  BZDL ,  412  from  952
# It took about  0.74 seconds
# The symbol  شبهرن  mode:  SSCL ,  413  from  952
#  It took about  0.72 seconds
# The symbol  شبهرن  mode:  SSDL ,  414  from  952
#  It took about  0.72 seconds
# The symbol  شبهرن  mode:  BZCL ,  415  from  952
# It took about  0.72 seconds
# The symbol  شبهرن  mode:  BZDL ,  416  from  952
# The symbol  شخارک  mode:  SSCL ,  417  from  952
#  It took about  0.84 seconds
# The symbol  شخارک  mode:  SSDL ,  418  from  952
#  It took about  0.77 seconds
# The symbol  شخارک  mode:  BZCL ,  419  from  952
# It took about  0.84 seconds
# The symbol  شخارک  mode:  BZDL ,  420  from  952
# It took about  0.72 seconds
# The symbol  شدوص  mode:  SSCL ,  421  from  952
#  It took about  0.71 seconds
# The symbol  شدوص  mode:  SSDL ,  422  from  952
#  It took about  0.78 seconds
# The symbol  شدوص  mode:  BZCL ,  423  from  952
# It took about  0.85 seconds
# The symbol  شدوص  mode:  BZDL ,  424  from  952
# It took about  0.75 seconds
# The symbol  شسینا  mode:  SSCL ,  425  from  952
#  It took about  0.85 seconds
# The symbol  شسینا  mode:  SSDL ,  426  from  952
#  It took about  0.75 seconds
# The symbol  شسینا  mode:  BZCL ,  427  from  952
# It took about  0.02 seconds
# The symbol  شسینا  mode:  BZDL ,  428  from  952
# It took about  0.72 seconds
# The symbol  شفارس  mode:  SSCL ,  429  from  952
# The symbol  شفارس  mode:  SSDL ,  430  from  952
# The symbol  شفارس  mode:  BZCL ,  431  from  952
# The symbol  شفارس  mode:  BZDL ,  432  from  952
# The symbol  شفن  mode:  SSCL ,  433  from  952
#  It took about  0.72 seconds
# The symbol  شفن  mode:  SSDL ,  434  from  952
#  It took about  0.71 seconds
# The symbol  شفن  mode:  BZCL ,  435  from  952
# It took about  0.87 seconds
# The symbol  شفن  mode:  BZDL ,  436  from  952
# It took about  0.72 seconds
# The symbol  شلعاب  mode:  SSCL ,  437  from  952
# The symbol  شلعاب  mode:  SSDL ,  438  from  952
# The symbol  شلعاب  mode:  BZCL ,  439  from  952
# The symbol  شلعاب  mode:  BZDL ,  440  from  952
# The symbol  شنفت  mode:  SSCL ,  441  from  952
#  It took about  0.87 seconds
# The symbol  شنفت  mode:  SSDL ,  442  from  952
#  It took about  0.91 seconds
# The symbol  شنفت  mode:  BZCL ,  443  from  952
# It took about  0.87 seconds
# The symbol  شنفت  mode:  BZDL ,  444  from  952
# It took about  0.9 seconds
# The symbol  شپارس  mode:  SSCL ,  445  from  952
# The symbol  شپارس  mode:  SSDL ,  446  from  952
# The symbol  شپارس  mode:  BZCL ,  447  from  952
# The symbol  شپارس  mode:  BZDL ,  448  from  952
# The symbol  شپاکسا  mode:  SSCL ,  449  from  952
#  It took about  0.74 seconds
# The symbol  شپاکسا  mode:  SSDL ,  450  from  952
#  It took about  0.02 seconds
# The symbol  شپاکسا  mode:  BZCL ,  451  from  952
# It took about  0.78 seconds
# The symbol  شپاکسا  mode:  BZDL ,  452  from  952
# The symbol  شپترو  mode:  SSCL ,  453  from  952
# The symbol  شپترو  mode:  SSDL ,  454  from  952
# The symbol  شپترو  mode:  BZCL ,  455  from  952
# The symbol  شپترو  mode:  BZDL ,  456  from  952
# The symbol  شپنا  mode:  SSCL ,  457  from  952
# The symbol  شپنا  mode:  SSDL ,  458  from  952
# The symbol  شپنا  mode:  BZCL ,  459  from  952
# The symbol  شپنا  mode:  BZDL ,  460  from  952
# The symbol  شکربن  mode:  SSCL ,  461  from  952
#  It took about  0.85 seconds
# The symbol  شکربن  mode:  SSDL ,  462  from  952
#  It took about  0.72 seconds
# The symbol  شکربن  mode:  BZCL ,  463  from  952
# It took about  0.86 seconds
# The symbol  شکربن  mode:  BZDL ,  464  from  952
# It took about  0.75 seconds
# The symbol  شکلر  mode:  SSCL ,  465  from  952
#  It took about  0.83 seconds
# The symbol  شکلر  mode:  SSDL ,  466  from  952
#  It took about  0.71 seconds
# The symbol  شکلر  mode:  BZCL ,  467  from  952
# It took about  0.73 seconds
# The symbol  شکلر  mode:  BZDL ,  468  from  952
# The symbol  شگل  mode:  SSCL ,  469  from  952
#  It took about  0.85 seconds
# The symbol  شگل  mode:  SSDL ,  470  from  952
#  It took about  0.87 seconds
# The symbol  شگل  mode:  BZCL ,  471  from  952
# It took about  0.75 seconds
# The symbol  شگل  mode:  BZDL ,  472  from  952
# The symbol  شیراز  mode:  SSCL ,  473  from  952
#  It took about  0.72 seconds
# The symbol  شیراز  mode:  SSDL ,  474  from  952
#  It took about  0.71 seconds
# The symbol  شیراز  mode:  BZCL ,  475  from  952
# It took about  0.82 seconds
# The symbol  شیراز  mode:  BZDL ,  476  from  952
# The symbol  شیران  mode:  SSCL ,  477  from  952
#  It took about  0.71 seconds
# The symbol  شیران  mode:  SSDL ,  478  from  952
#  It took about  0.78 seconds
# The symbol  شیران  mode:  BZCL ,  479  from  952
# It took about  0.84 seconds
# The symbol  شیران  mode:  BZDL ,  480  from  952
# The symbol  غالبر  mode:  SSCL ,  481  from  952
#  It took about  0.72 seconds
# The symbol  غالبر  mode:  SSDL ,  482  from  952
#  It took about  0.94 seconds
# The symbol  غالبر  mode:  BZCL ,  483  from  952
# It took about  0.72 seconds
# The symbol  غالبر  mode:  BZDL ,  484  from  952
# The symbol  غبشهر  mode:  SSCL ,  485  from  952
#  It took about  0.72 seconds
# The symbol  غبشهر  mode:  SSDL ,  486  from  952
#  It took about  0.87 seconds
# The symbol  غبشهر  mode:  BZCL ,  487  from  952
# It took about  0.93 seconds
# The symbol  غبشهر  mode:  BZDL ,  488  from  952
# The symbol  غبهنوش  mode:  SSCL ,  489  from  952
# The symbol  غبهنوش  mode:  SSDL ,  490  from  952
# The symbol  غبهنوش  mode:  BZCL ,  491  from  952
# The symbol  غبهنوش  mode:  BZDL ,  492  from  952
# The symbol  غدام  mode:  SSCL ,  493  from  952
# The symbol  غدام  mode:  SSDL ,  494  from  952
# The symbol  غدام  mode:  BZCL ,  495  from  952
# The symbol  غدام  mode:  BZDL ,  496  from  952
# The symbol  غدشت  mode:  SSCL ,  497  from  952
#  It took about  0.75 seconds
# The symbol  غدشت  mode:  SSDL ,  498  from  952
#  It took about  0.72 seconds
# The symbol  غدشت  mode:  BZCL ,  499  from  952
# It took about  0.73 seconds
# The symbol  غدشت  mode:  BZDL ,  500  from  952
# The symbol  غسالم  mode:  SSCL ,  501  from  952
#  It took about  0.71 seconds
# The symbol  غسالم  mode:  SSDL ,  502  from  952
#  It took about  0.87 seconds
# The symbol  غسالم  mode:  BZCL ,  503  from  952
# It took about  0.71 seconds
# The symbol  غسالم  mode:  BZDL ,  504  from  952
# It took about  0.87 seconds
# The symbol  غشان  mode:  SSCL ,  505  from  952
#  It took about  0.7 seconds
# The symbol  غشان  mode:  SSDL ,  506  from  952
#  It took about  0.87 seconds
# The symbol  غشان  mode:  BZCL ,  507  from  952
# It took about  0.71 seconds
# The symbol  غشان  mode:  BZDL ,  508  from  952
# The symbol  غشصفا  mode:  SSCL ,  509  from  952
#  It took about  0.72 seconds
# The symbol  غشصفا  mode:  SSDL ,  510  from  952
#  It took about  0.88 seconds
# The symbol  غشصفا  mode:  BZCL ,  511  from  952
# It took about  0.06 seconds
# The symbol  غشصفا  mode:  BZDL ,  512  from  952
# The symbol  غمارگ  mode:  SSCL ,  513  from  952
#  It took about  0.85 seconds
# The symbol  غمارگ  mode:  SSDL ,  514  from  952
#  It took about  0.82 seconds
# The symbol  غمارگ  mode:  BZCL ,  515  from  952
# It took about  0.71 seconds
# The symbol  غمارگ  mode:  BZDL ,  516  from  952
# The symbol  غمهرا  mode:  SSCL ,  517  from  952
#  It took about  0.71 seconds
# The symbol  غمهرا  mode:  SSDL ,  518  from  952
#  It took about  0.94 seconds
# The symbol  غمهرا  mode:  BZCL ,  519  from  952
# It took about  0.71 seconds
# The symbol  غمهرا  mode:  BZDL ,  520  from  952
# The symbol  غنوش  mode:  SSCL ,  521  from  952
#  It took about  0.86 seconds
# The symbol  غنوش  mode:  SSDL ,  522  from  952
#  It took about  0.83 seconds
# The symbol  غنوش  mode:  BZCL ,  523  from  952
# It took about  0.73 seconds
# The symbol  غنوش  mode:  BZDL ,  524  from  952
# It took about  0.84 seconds
# The symbol  غچین  mode:  SSCL ,  525  from  952
# The symbol  غچین  mode:  SSDL ,  526  from  952
# The symbol  غچین  mode:  BZCL ,  527  from  952
# The symbol  غچین  mode:  BZDL ,  528  from  952
# The symbol  فاذر  mode:  SSCL ,  529  from  952
#  It took about  0.75 seconds
# The symbol  فاذر  mode:  SSDL ,  530  from  952
#  It took about  0.87 seconds
# The symbol  فاذر  mode:  BZCL ,  531  from  952
# It took about  0.77 seconds
# The symbol  فاذر  mode:  BZDL ,  532  from  952
# It took about  0.71 seconds
# The symbol  فاراک  mode:  SSCL ,  533  from  952
# The symbol  فاراک  mode:  SSDL ,  534  from  952
# The symbol  فاراک  mode:  BZCL ,  535  from  952
# The symbol  فاراک  mode:  BZDL ,  536  from  952
# The symbol  فاسمین  mode:  SSCL ,  537  from  952
#  It took about  0.86 seconds
# The symbol  فاسمین  mode:  SSDL ,  538  from  952
#  It took about  0.75 seconds
# The symbol  فاسمین  mode:  BZCL ,  539  from  952
# It took about  0.01 seconds
# The symbol  فاسمین  mode:  BZDL ,  540  from  952
# It took about  0.72 seconds
# The symbol  فاما  mode:  SSCL ,  541  from  952
#  It took about  0.9 seconds
# The symbol  فاما  mode:  SSDL ,  542  from  952
#  It took about  0.72 seconds
# The symbol  فاما  mode:  BZCL ,  543  from  952
# It took about  0.83 seconds
# The symbol  فاما  mode:  BZDL ,  544  from  952
# It took about  0.72 seconds
# The symbol  فایرا  mode:  SSCL ,  545  from  952
#  It took about  0.83 seconds
# The symbol  فایرا  mode:  SSDL ,  546  from  952
#  It took about  0.86 seconds
# The symbol  فایرا  mode:  BZCL ,  547  from  952
# It took about  0.87 seconds
# The symbol  فایرا  mode:  BZDL ,  548  from  952
# The symbol  فباهنر  mode:  SSCL ,  549  from  952
# The symbol  فباهنر  mode:  SSDL ,  550  from  952
# The symbol  فباهنر  mode:  BZCL ,  551  from  952
# The symbol  فباهنر  mode:  BZDL ,  552  from  952
# The symbol  فجام  mode:  SSCL ,  553  from  952
#  It took about  0.74 seconds
# The symbol  فجام  mode:  SSDL ,  554  from  952
#  It took about  0.85 seconds
# The symbol  فجام  mode:  BZCL ,  555  from  952
# It took about  0.73 seconds
# The symbol  فجام  mode:  BZDL ,  556  from  952
# The symbol  فجر  mode:  SSCL ,  557  from  952
#  It took about  0.71 seconds
# The symbol  فجر  mode:  SSDL ,  558  from  952
#  It took about  0.86 seconds
# The symbol  فجر  mode:  BZCL ,  559  from  952
# It took about  0.78 seconds
# The symbol  فجر  mode:  BZDL ,  560  from  952
# It took about  0.82 seconds
# The symbol  فخاس  mode:  SSCL ,  561  from  952
#  It took about  0.78 seconds
# The symbol  فخاس  mode:  SSDL ,  562  from  952
#  It took about  0.84 seconds
# The symbol  فخاس  mode:  BZCL ,  563  from  952
# It took about  0.94 seconds
# The symbol  فخاس  mode:  BZDL ,  564  from  952
# The symbol  فخوز  mode:  SSCL ,  565  from  952
#  It took about  0.79 seconds
# The symbol  فخوز  mode:  SSDL ,  566  from  952
#  It took about  0.72 seconds
# The symbol  فخوز  mode:  BZCL ,  567  from  952
# It took about  0.71 seconds
# The symbol  فخوز  mode:  BZDL ,  568  from  952
# The symbol  فرآور  mode:  SSCL ,  569  from  952
# The symbol  فرآور  mode:  SSDL ,  570  from  952
# The symbol  فرآور  mode:  BZCL ,  571  from  952
# The symbol  فرآور  mode:  BZDL ,  572  from  952
# The symbol  فروس  mode:  SSCL ,  573  from  952
#  It took about  0.84 seconds
# The symbol  فروس  mode:  SSDL ,  574  from  952
#  It took about  0.73 seconds
# The symbol  فروس  mode:  BZCL ,  575  from  952
# It took about  0.82 seconds
# The symbol  فروس  mode:  BZDL ,  576  from  952
# The symbol  فسرب  mode:  SSCL ,  577  from  952
#  It took about  0.7 seconds
# The symbol  فسرب  mode:  SSDL ,  578  from  952
#  It took about  0.02 seconds
# The symbol  فسرب  mode:  BZCL ,  579  from  952
# It took about  0.87 seconds
# The symbol  فسرب  mode:  BZDL ,  580  from  952
# It took about  0.72 seconds
# The symbol  فسپا  mode:  SSCL ,  581  from  952
#  It took about  0.8 seconds
# The symbol  فسپا  mode:  SSDL ,  582  from  952
#  It took about  0.8 seconds
# The symbol  فسپا  mode:  BZCL ,  583  from  952
# It took about  0.95 seconds
# The symbol  فسپا  mode:  BZDL ,  584  from  952
# The symbol  فلامی  mode:  SSCL ,  585  from  952
#  It took about  0.74 seconds
# The symbol  فلامی  mode:  SSDL ,  586  from  952
#  It took about  0.82 seconds
# The symbol  فلامی  mode:  BZCL ,  587  from  952
# It took about  0.76 seconds
# The symbol  فلامی  mode:  BZDL ,  588  from  952
# It took about  0.9 seconds
# The symbol  فلوله  mode:  SSCL ,  589  from  952
#  It took about  0.71 seconds
# The symbol  فلوله  mode:  SSDL ,  590  from  952
#  It took about  0.75 seconds
# The symbol  فلوله  mode:  BZCL ,  591  from  952
# It took about  0.81 seconds
# The symbol  فلوله  mode:  BZDL ,  592  from  952
# It took about  0.71 seconds
# The symbol  فمراد  mode:  SSCL ,  593  from  952
# The symbol  فمراد  mode:  SSDL ,  594  from  952
# The symbol  فمراد  mode:  BZCL ,  595  from  952
# The symbol  فمراد  mode:  BZDL ,  596  from  952
# The symbol  فملی  mode:  SSCL ,  597  from  952
#  It took about  0.71 seconds
# The symbol  فملی  mode:  SSDL ,  598  from  952
#  It took about  0.96 seconds
# The symbol  فملی  mode:  BZCL ,  599  from  952
# It took about  0.72 seconds
# The symbol  فملی  mode:  BZDL ,  600  from  952
# The symbol  فنوال  mode:  SSCL ,  601  from  952
#  It took about  0.89 seconds
# The symbol  فنوال  mode:  SSDL ,  602  from  952
#  It took about  0.73 seconds
# The symbol  فنوال  mode:  BZCL ,  603  from  952
# It took about  0.87 seconds
# The symbol  فنوال  mode:  BZDL ,  604  from  952
# The symbol  فنورد  mode:  SSCL ,  605  from  952
#  It took about  0.71 seconds
# The symbol  فنورد  mode:  SSDL ,  606  from  952
#  It took about  0.78 seconds
# The symbol  فنورد  mode:  BZCL ,  607  from  952
# It took about  0.71 seconds
# The symbol  فنورد  mode:  BZDL ,  608  from  952
# The symbol  فولاد  mode:  SSCL ,  609  from  952
#  It took about  0.98 seconds
# The symbol  فولاد  mode:  SSDL ,  610  from  952
#  It took about  0.87 seconds
# The symbol  فولاد  mode:  BZCL ,  611  from  952
# It took about  0.74 seconds
# The symbol  فولاد  mode:  BZDL ,  612  from  952
# It took about  0.98 seconds
# The symbol  فپنتا  mode:  SSCL ,  613  from  952
#  It took about  0.71 seconds
# The symbol  فپنتا  mode:  SSDL ,  614  from  952
#  It took about  0.72 seconds
# The symbol  فپنتا  mode:  BZCL ,  615  from  952
# It took about  0.74 seconds
# The symbol  فپنتا  mode:  BZDL ,  616  from  952
# The symbol  قثابت  mode:  SSCL ,  617  from  952
#  It took about  0.01 seconds
# The symbol  قثابت  mode:  SSDL ,  618  from  952
#  It took about  0.83 seconds
# The symbol  قثابت  mode:  BZCL ,  619  from  952
# It took about  0.77 seconds
# The symbol  قثابت  mode:  BZDL ,  620  from  952
# The symbol  قشکر  mode:  SSCL ,  621  from  952
#  It took about  0.91 seconds
# The symbol  قشکر  mode:  SSDL ,  622  from  952
#  It took about  0.78 seconds
# The symbol  قشکر  mode:  BZCL ,  623  from  952
# It took about  0.92 seconds
# The symbol  قشکر  mode:  BZDL ,  624  from  952
# It took about  0.86 seconds
# The symbol  قمرو  mode:  SSCL ,  625  from  952
# The symbol  قمرو  mode:  SSDL ,  626  from  952
# The symbol  قمرو  mode:  BZCL ,  627  from  952
# The symbol  قمرو  mode:  BZDL ,  628  from  952
# The symbol  قنیشا  mode:  SSCL ,  629  from  952
# The symbol  قنیشا  mode:  SSDL ,  630  from  952
# The symbol  قنیشا  mode:  BZCL ,  631  from  952
# The symbol  قنیشا  mode:  BZDL ,  632  from  952
# The symbol  قپیرا  mode:  SSCL ,  633  from  952
#  It took about  0.8 seconds
# The symbol  قپیرا  mode:  SSDL ,  634  from  952
#  It took about  0.71 seconds
# The symbol  قپیرا  mode:  BZCL ,  635  from  952
# It took about  0.83 seconds
# The symbol  قپیرا  mode:  BZDL ,  636  from  952
# It took about  0.7 seconds
# The symbol  لابسا  mode:  SSCL ,  637  from  952
#  It took about  0.88 seconds
# The symbol  لابسا  mode:  SSDL ,  638  from  952
#  It took about  0.84 seconds
# The symbol  لابسا  mode:  BZCL ,  639  from  952
# It took about  0.98 seconds
# The symbol  لابسا  mode:  BZDL ,  640  from  952
# The symbol  لبوتان  mode:  SSCL ,  641  from  952
#  It took about  0.85 seconds
# The symbol  لبوتان  mode:  SSDL ,  642  from  952
#  It took about  0.77 seconds
# The symbol  لبوتان  mode:  BZCL ,  643  from  952
# It took about  0.84 seconds
# The symbol  لبوتان  mode:  BZDL ,  644  from  952
# The symbol  لخزر  mode:  SSCL ,  645  from  952
#  It took about  0.76 seconds
# The symbol  لخزر  mode:  SSDL ,  646  from  952
#  It took about  0.87 seconds
# The symbol  لخزر  mode:  BZCL ,  647  from  952
# It took about  0.74 seconds
# The symbol  لخزر  mode:  BZDL ,  648  from  952
# It took about  0.72 seconds
# The symbol  لسرما  mode:  SSCL ,  649  from  952
#  It took about  0.86 seconds
# The symbol  لسرما  mode:  SSDL ,  650  from  952
#  It took about  0.79 seconds
# The symbol  لسرما  mode:  BZCL ,  651  from  952
# It took about  0.73 seconds
# The symbol  لسرما  mode:  BZDL ,  652  from  952
# It took about  0.86 seconds
# The symbol  لپارس  mode:  SSCL ,  653  from  952
# The symbol  لپارس  mode:  SSDL ,  654  from  952
# The symbol  لپارس  mode:  BZCL ,  655  from  952
# The symbol  لپارس  mode:  BZDL ,  656  from  952
# The symbol  مداران  mode:  SSCL ,  657  from  952
# The symbol  مداران  mode:  SSDL ,  658  from  952
# The symbol  مداران  mode:  BZCL ,  659  from  952
# The symbol  مداران  mode:  BZDL ,  660  from  952
# The symbol  مرقام  mode:  SSCL ,  661  from  952
# The symbol  مرقام  mode:  SSDL ,  662  from  952
# The symbol  مرقام  mode:  BZCL ,  663  from  952
# The symbol  مرقام  mode:  BZDL ,  664  from  952
# The symbol  نبروج  mode:  SSCL ,  665  from  952
# The symbol  نبروج  mode:  SSDL ,  666  from  952
# The symbol  نبروج  mode:  BZCL ,  667  from  952
# The symbol  نبروج  mode:  BZDL ,  668  from  952
# The symbol  نمرینو  mode:  SSCL ,  669  from  952
#  It took about  0.73 seconds
# The symbol  نمرینو  mode:  SSDL ,  670  from  952
#  It took about  0.85 seconds
# The symbol  نمرینو  mode:  BZCL ,  671  from  952
# It took about  0.71 seconds
# The symbol  نمرینو  mode:  BZDL ,  672  from  952
# It took about  0.83 seconds
# The symbol  وآذر  mode:  SSCL ,  673  from  952
#  It took about  0.7 seconds
# The symbol  وآذر  mode:  SSDL ,  674  from  952
#  It took about  0.88 seconds
# The symbol  وآذر  mode:  BZCL ,  675  from  952
# It took about  0.72 seconds
# The symbol  وآذر  mode:  BZDL ,  676  from  952
# It took about  0.86 seconds
# The symbol  واتی  mode:  SSCL ,  677  from  952
#  It took about  0.82 seconds
# The symbol  واتی  mode:  SSDL ,  678  from  952
#  It took about  0.76 seconds
# The symbol  واتی  mode:  BZCL ,  679  from  952
# It took about  0.85 seconds
# The symbol  واتی  mode:  BZDL ,  680  from  952
# The symbol  واعتبار  mode:  SSCL ,  681  from  952
# The symbol  واعتبار  mode:  SSDL ,  682  from  952
# The symbol  واعتبار  mode:  BZCL ,  683  from  952
# The symbol  واعتبار  mode:  BZDL ,  684  from  952
# The symbol  والبر  mode:  SSCL ,  685  from  952
# The symbol  والبر  mode:  SSDL ,  686  from  952
# The symbol  والبر  mode:  BZCL ,  687  from  952
# The symbol  والبر  mode:  BZDL ,  688  from  952
# The symbol  وبشهر  mode:  SSCL ,  689  from  952
#  It took about  0.9 seconds
# The symbol  وبشهر  mode:  SSDL ,  690  from  952
#  It took about  0.8 seconds
# The symbol  وبشهر  mode:  BZCL ,  691  from  952
# It took about  0.72 seconds
# The symbol  وبشهر  mode:  BZDL ,  692  from  952
# It took about  0.82 seconds
# The symbol  وبملت  mode:  SSCL ,  693  from  952
# The symbol  وبملت  mode:  SSDL ,  694  from  952
# The symbol  وبملت  mode:  BZCL ,  695  from  952
# The symbol  وبملت  mode:  BZDL ,  696  from  952
# The symbol  وبهمن  mode:  SSCL ,  697  from  952
#  It took about  0.72 seconds
# The symbol  وبهمن  mode:  SSDL ,  698  from  952
#  It took about  0.78 seconds
# The symbol  وبهمن  mode:  BZCL ,  699  from  952
# It took about  0.88 seconds
# The symbol  وبهمن  mode:  BZDL ,  700  from  952
# It took about  0.83 seconds
# The symbol  وبوعلی  mode:  SSCL ,  701  from  952
#  It took about  0.74 seconds
# The symbol  وبوعلی  mode:  SSDL ,  702  from  952
#  It took about  0.34 seconds
# The symbol  وبوعلی  mode:  BZCL ,  703  from  952
# It took about  0.74 seconds
# The symbol  وبوعلی  mode:  BZDL ,  704  from  952
# The symbol  وبیمه  mode:  SSCL ,  705  from  952
#  It took about  0.88 seconds
# The symbol  وبیمه  mode:  SSDL ,  706  from  952
#  It took about  0.78 seconds
# The symbol  وبیمه  mode:  BZCL ,  707  from  952
# It took about  0.73 seconds
# The symbol  وبیمه  mode:  BZDL ,  708  from  952
# It took about  0.8 seconds
# The symbol  وتوس  mode:  SSCL ,  709  from  952
#  It took about  0.84 seconds
# The symbol  وتوس  mode:  SSDL ,  710  from  952
#  It took about  0.88 seconds
# The symbol  وتوس  mode:  BZCL ,  711  from  952
# It took about  0.93 seconds
# The symbol  وتوس  mode:  BZDL ,  712  from  952
# It took about  0.76 seconds
# ...
#  It took about  0.83 seconds
# The symbol  وتوسم  mode:  SSDL ,  714  from  952
#  It took about  0.79 seconds
# The symbol  وتوسم  mode:  BZCL ,  715  from  952
# It took about  0.87 seconds
# The symbol  وتوسم  mode:  BZDL ,  716  from  952
# The symbol  وتوشه  mode:  SSCL ,  717  from  952
#  It took about  0.79 seconds
# The symbol  وتوشه  mode:  SSDL ,  718  from  952
#  It took about  0.72 seconds
# The symbol  وتوشه  mode:  BZCL ,  719  from  952
# It took about  0.83 seconds
# The symbol  وتوشه  mode:  BZDL ,  720  from  952
# The symbol  وتوصا  mode:  SSCL ,  721  from  952
#  It took about  0.85 seconds
# The symbol  وتوصا  mode:  SSDL ,  722  from  952
#  It took about  0.85 seconds
# The symbol  وتوصا  mode:  BZCL ,  723  from  952
# It took about  0.78 seconds
# The symbol  وتوصا  mode:  BZDL ,  724  from  952
# It took about  0.86 seconds
# The symbol  وتوکا  mode:  SSCL ,  725  from  952
#  It took about  0.71 seconds
# The symbol  وتوکا  mode:  SSDL ,  726  from  952
#  It took about  0.9 seconds
# The symbol  وتوکا  mode:  BZCL ,  727  from  952
# It took about  0.06 seconds
# The symbol  وتوکا  mode:  BZDL ,  728  from  952
# It took about  0.87 seconds
# The symbol  ورنا  mode:  SSCL ,  729  from  952
#  It took about  0.88 seconds
# The symbol  ورنا  mode:  SSDL ,  730  from  952
#  It took about  0.87 seconds
# The symbol  ورنا  mode:  BZCL ,  731  from  952
# It took about  0.9 seconds
# The symbol  ورنا  mode:  BZDL ,  732  from  952
# The symbol  وساخت  mode:  SSCL ,  733  from  952
#  It took about  0.79 seconds
# The symbol  وساخت  mode:  SSDL ,  734  from  952
#  It took about  0.74 seconds
# The symbol  وساخت  mode:  BZCL ,  735  from  952
# It took about  0.72 seconds
# The symbol  وساخت  mode:  BZDL ,  736  from  952
# It took about  0.9 seconds
# The symbol  وساپا  mode:  SSCL ,  737  from  952
# The symbol  وساپا  mode:  SSDL ,  738  from  952
# The symbol  وساپا  mode:  BZCL ,  739  from  952
# The symbol  وساپا  mode:  BZDL ,  740  from  952
# The symbol  وسپه  mode:  SSCL ,  741  from  952
# The symbol  وسپه  mode:  SSDL ,  742  from  952
# The symbol  وسپه  mode:  BZCL ,  743  from  952
# The symbol  وسپه  mode:  BZDL ,  744  from  952
# The symbol  وسینا  mode:  SSCL ,  745  from  952
#  It took about  0.73 seconds
# The symbol  وسینا  mode:  SSDL ,  746  from  952
#  It took about  0.86 seconds
# The symbol  وسینا  mode:  BZCL ,  747  from  952
# It took about  0.94 seconds
# The symbol  وسینا  mode:  BZDL ,  748  from  952
# The symbol  وصنا  mode:  SSCL ,  749  from  952
#  It took about  0.83 seconds
# The symbol  وصنا  mode:  SSDL ,  750  from  952
#  It took about  0.77 seconds
# The symbol  وصنا  mode:  BZCL ,  751  from  952
# It took about  0.72 seconds
# The symbol  وصنا  mode:  BZDL ,  752  from  952
# The symbol  وصنعت  mode:  SSCL ,  753  from  952
#  It took about  0.73 seconds
# The symbol  وصنعت  mode:  SSDL ,  754  from  952
#  It took about  0.84 seconds
# The symbol  وصنعت  mode:  BZCL ,  755  from  952
# It took about  0.73 seconds
# The symbol  وصنعت  mode:  BZDL ,  756  from  952
# It took about  0.03 seconds
# The symbol  ولساپا  mode:  SSCL ,  757  from  952
# The symbol  ولساپا  mode:  SSDL ,  758  from  952
# The symbol  ولساپا  mode:  BZCL ,  759  from  952
# The symbol  ولساپا  mode:  BZDL ,  760  from  952
# The symbol  ولصنم  mode:  SSCL ,  761  from  952
#  It took about  0.72 seconds
# The symbol  ولصنم  mode:  SSDL ,  762  from  952
#  It took about  0.89 seconds
# The symbol  ولصنم  mode:  BZCL ,  763  from  952
# It took about  0.72 seconds
# The symbol  ولصنم  mode:  BZDL ,  764  from  952
# The symbol  ولغدر  mode:  SSCL ,  765  from  952
#  It took about  0.97 seconds
# The symbol  ولغدر  mode:  SSDL ,  766  from  952
#  It took about  0.72 seconds
# The symbol  ولغدر  mode:  BZCL ,  767  from  952
# It took about  0.72 seconds
# The symbol  ولغدر  mode:  BZDL ,  768  from  952
# The symbol  ولیز  mode:  SSCL ,  769  from  952
#  It took about  0.76 seconds
# The symbol  ولیز  mode:  SSDL ,  770  from  952
#  It took about  0.74 seconds
# The symbol  ولیز  mode:  BZCL ,  771  from  952
# It took about  0.71 seconds
# The symbol  ولیز  mode:  BZDL ,  772  from  952
# The symbol  ومعادن  mode:  SSCL ,  773  from  952
#  It took about  0.04 seconds
# The symbol  ومعادن  mode:  SSDL ,  774  from  952
#  It took about  0.71 seconds
# The symbol  ومعادن  mode:  BZCL ,  775  from  952
# It took about  0.72 seconds
# The symbol  ومعادن  mode:  BZDL ,  776  from  952
# It took about  0.87 seconds
# The symbol  وملی  mode:  SSCL ,  777  from  952
# The symbol  وملی  mode:  SSDL ,  778  from  952
# The symbol  وملی  mode:  BZCL ,  779  from  952
# The symbol  وملی  mode:  BZDL ,  780  from  952
# The symbol  ونفت  mode:  SSCL ,  781  from  952
#  It took about  0.73 seconds
# The symbol  ونفت  mode:  SSDL ,  782  from  952
#  It took about  0.04 seconds
# The symbol  ونفت  mode:  BZCL ,  783  from  952
# It took about  0.8 seconds
# The symbol  ونفت  mode:  BZDL ,  784  from  952
# It took about  0.85 seconds
# The symbol  ونوین  mode:  SSCL ,  785  from  952
#  It took about  0.72 seconds
# The symbol  ونوین  mode:  SSDL ,  786  from  952
#  It took about  0.97 seconds
# The symbol  ونوین  mode:  BZCL ,  787  from  952
# It took about  0.84 seconds
# The symbol  ونوین  mode:  BZDL ,  788  from  952
# It took about  0.73 seconds
# The symbol  ونیرو  mode:  SSCL ,  789  from  952
#  It took about  0.73 seconds
# The symbol  ونیرو  mode:  SSDL ,  790  from  952
#  It took about  0.83 seconds
# The symbol  ونیرو  mode:  BZCL ,  791  from  952
# It took about  0.82 seconds
# The symbol  ونیرو  mode:  BZDL ,  792  from  952
# It took about  0.86 seconds
# The symbol  ونیکی  mode:  SSCL ,  793  from  952
#  It took about  0.72 seconds
# The symbol  ونیکی  mode:  SSDL ,  794  from  952
#  It took about  0.86 seconds
# The symbol  ونیکی  mode:  BZCL ,  795  from  952
# It took about  0.72 seconds
# The symbol  ونیکی  mode:  BZDL ,  796  from  952
# It took about  0.72 seconds
# The symbol  وپارس  mode:  SSCL ,  797  from  952
#  It took about  0.72 seconds
# The symbol  وپارس  mode:  SSDL ,  798  from  952
#  It took about  0.73 seconds
# The symbol  وپارس  mode:  BZCL ,  799  from  952
# It took about  0.81 seconds
# The symbol  وپارس  mode:  BZDL ,  800  from  952
# It took about  0.71 seconds
# The symbol  وپترو  mode:  SSCL ,  801  from  952
#  It took about  0.83 seconds
# The symbol  وپترو  mode:  SSDL ,  802  from  952
#  It took about  0.74 seconds
# The symbol  وپترو  mode:  BZCL ,  803  from  952
# It took about  0.72 seconds
# The symbol  وپترو  mode:  BZDL ,  804  from  952
# The symbol  وپخش  mode:  SSCL ,  805  from  952
# The symbol  وپخش  mode:  SSDL ,  806  from  952
# The symbol  وپخش  mode:  BZCL ,  807  from  952
# The symbol  وپخش  mode:  BZDL ,  808  from  952
# The symbol  وکار  mode:  SSCL ,  809  from  952
#  It took about  0.71 seconds
# The symbol  وکار  mode:  SSDL ,  810  from  952
#  It took about  0.92 seconds
# The symbol  وکار  mode:  BZCL ,  811  from  952
# It took about  0.74 seconds
# The symbol  وکار  mode:  BZDL ,  812  from  952
# The symbol  پاسا  mode:  SSCL ,  813  from  952
#  It took about  0.86 seconds
# The symbol  پاسا  mode:  SSDL ,  814  from  952
#  It took about  0.74 seconds
# The symbol  پاسا  mode:  BZCL ,  815  from  952
# It took about  0.7 seconds
# The symbol  پاسا  mode:  BZDL ,  816  from  952
# It took about  0.71 seconds
# The symbol  پتایر  mode:  SSCL ,  817  from  952
# The symbol  پتایر  mode:  SSDL ,  818  from  952
# The symbol  پتایر  mode:  BZCL ,  819  from  952
# The symbol  پتایر  mode:  BZDL ,  820  from  952
# The symbol  پدرخش  mode:  SSCL ,  821  from  952
#  It took about  0.84 seconds
# The symbol  پدرخش  mode:  SSDL ,  822  from  952
#  It took about  0.83 seconds
# The symbol  پدرخش  mode:  BZCL ,  823  from  952
# It took about  0.73 seconds
# The symbol  پدرخش  mode:  BZDL ,  824  from  952
# The symbol  پردیس  mode:  SSCL ,  825  from  952
# The symbol  پردیس  mode:  SSDL ,  826  from  952
# The symbol  پردیس  mode:  BZCL ,  827  from  952
# The symbol  پردیس  mode:  BZDL ,  828  from  952
# The symbol  پسهند  mode:  SSCL ,  829  from  952
#  It took about  0.72 seconds
# The symbol  پسهند  mode:  SSDL ,  830  from  952
#  It took about  0.95 seconds
# The symbol  پسهند  mode:  BZCL ,  831  from  952
# It took about  0.95 seconds
# The symbol  پسهند  mode:  BZDL ,  832  from  952
# The symbol  پلاسک  mode:  SSCL ,  833  from  952
# The symbol  پلاسک  mode:  SSDL ,  834  from  952
# The symbol  پلاسک  mode:  BZCL ,  835  from  952
# The symbol  پلاسک  mode:  BZDL ,  836  from  952
# The symbol  پکرمان  mode:  SSCL ,  837  from  952
# The symbol  پکرمان  mode:  SSDL ,  838  from  952
# The symbol  پکرمان  mode:  BZCL ,  839  from  952
# The symbol  پکرمان  mode:  BZDL ,  840  from  952
# The symbol  چافست  mode:  SSCL ,  841  from  952
#  It took about  0.88 seconds
# The symbol  چافست  mode:  SSDL ,  842  from  952
#  It took about  0.85 seconds
# The symbol  چافست  mode:  BZCL ,  843  from  952
# It took about  0.75 seconds
# The symbol  چافست  mode:  BZDL ,  844  from  952
# The symbol  چفیبر  mode:  SSCL ,  845  from  952
#  It took about  0.83 seconds
# The symbol  چفیبر  mode:  SSDL ,  846  from  952
#  It took about  0.75 seconds
# The symbol  چفیبر  mode:  BZCL ,  847  from  952
# It took about  0.84 seconds
# The symbol  چفیبر  mode:  BZDL ,  848  from  952
# It took about  0.03 seconds
# The symbol  چکارن  mode:  SSCL ,  849  from  952
#  It took about  0.78 seconds
# The symbol  چکارن  mode:  SSDL ,  850  from  952
#  It took about  0.88 seconds
# The symbol  چکارن  mode:  BZCL ,  851  from  952
# It took about  0.7 seconds
# The symbol  چکارن  mode:  BZDL ,  852  from  952
# It took about  0.72 seconds
# The symbol  چکاوه  mode:  SSCL ,  853  from  952
# The symbol  چکاوه  mode:  SSDL ,  854  from  952
# The symbol  چکاوه  mode:  BZCL ,  855  from  952
# The symbol  چکاوه  mode:  BZDL ,  856  from  952
# The symbol  کاذر  mode:  SSCL ,  857  from  952
#  It took about  0.72 seconds
# The symbol  کاذر  mode:  SSDL ,  858  from  952
#  It took about  0.72 seconds
# The symbol  کاذر  mode:  BZCL ,  859  from  952
# It took about  0.01 seconds
# The symbol  کاذر  mode:  BZDL ,  860  from  952
# The symbol  کاما  mode:  SSCL ,  861  from  952
#  It took about  0.82 seconds
# The symbol  کاما  mode:  SSDL ,  862  from  952
#  It took about  0.73 seconds
# The symbol  کاما  mode:  BZCL ,  863  from  952
# It took about  0.87 seconds
# The symbol  کاما  mode:  BZDL ,  864  from  952
# The symbol  کبافق  mode:  SSCL ,  865  from  952
# The symbol  کبافق  mode:  SSDL ,  866  from  952
# The symbol  کبافق  mode:  BZCL ,  867  from  952
# The symbol  کبافق  mode:  BZDL ,  868  from  952
# The symbol  کحافظ  mode:  SSCL ,  869  from  952
#  It took about  0.75 seconds
# The symbol  کحافظ  mode:  SSDL ,  870  from  952
#  It took about  0.86 seconds
# The symbol  کحافظ  mode:  BZCL ,  871  from  952
# It took about  0.84 seconds
# The symbol  کحافظ  mode:  BZDL ,  872  from  952
# The symbol  کخاک  mode:  SSCL ,  873  from  952
# The symbol  کخاک  mode:  SSDL ,  874  from  952
# The symbol  کخاک  mode:  BZCL ,  875  from  952
# The symbol  کخاک  mode:  BZDL ,  876  from  952
# The symbol  کدما  mode:  SSCL ,  877  from  952
# The symbol  کدما  mode:  SSDL ,  878  from  952
# The symbol  کدما  mode:  BZCL ,  879  from  952
# The symbol  کدما  mode:  BZDL ,  880  from  952
# The symbol  کرازی  mode:  SSCL ,  881  from  952
#  It took about  0.72 seconds
# The symbol  کرازی  mode:  SSDL ,  882  from  952
#  It took about  0.87 seconds
# The symbol  کرازی  mode:  BZCL ,  883  from  952
# It took about  0.82 seconds
# The symbol  کرازی  mode:  BZDL ,  884  from  952
# The symbol  کروی  mode:  SSCL ,  885  from  952
#  It took about  0.87 seconds
# The symbol  کروی  mode:  SSDL ,  886  from  952
#  It took about  0.71 seconds
# The symbol  کروی  mode:  BZCL ,  887  from  952
# It took about  0.86 seconds
# The symbol  کروی  mode:  BZDL ,  888  from  952
# It took about  0.73 seconds
# The symbol  کساوه  mode:  SSCL ,  889  from  952
# The symbol  کساوه  mode:  SSDL ,  890  from  952
# The symbol  کساوه  mode:  BZCL ,  891  from  952
# The symbol  کساوه  mode:  BZDL ,  892  from  952
# The symbol  کساپا  mode:  SSCL ,  893  from  952
# The symbol  کساپا  mode:  SSDL ,  894  from  952
# The symbol  کساپا  mode:  BZCL ,  895  from  952
# The symbol  کساپا  mode:  BZDL ,  896  from  952
# The symbol  کسرا  mode:  SSCL ,  897  from  952
#  It took about  0.96 seconds
# The symbol  کسرا  mode:  SSDL ,  898  from  952
#  It took about  0.74 seconds
# The symbol  کسرا  mode:  BZCL ,  899  from  952
# It took about  0.72 seconds
# The symbol  کسرا  mode:  BZDL ,  900  from  952
# It took about  0.72 seconds
# The symbol  کسرام  mode:  SSCL ,  901  from  952
#  It took about  0.83 seconds
# The symbol  کسرام  mode:  SSDL ,  902  from  952
#  It took about  0.76 seconds
# The symbol  کسرام  mode:  BZCL ,  903  from  952
# It took about  0.86 seconds
# The symbol  کسرام  mode:  BZDL ,  904  from  952
# The symbol  کسعدی  mode:  SSCL ,  905  from  952
#  It took about  0.85 seconds
# The symbol  کسعدی  mode:  SSDL ,  906  from  952
#  It took about  0.83 seconds
# The symbol  کسعدی  mode:  BZCL ,  907  from  952
# It took about  0.02 seconds
# The symbol  کسعدی  mode:  BZDL ,  908  from  952
# It took about  0.76 seconds
# The symbol  کطبس  mode:  SSCL ,  909  from  952
#  It took about  0.62 seconds
# The symbol  کطبس  mode:  SSDL ,  910  from  952
#  It took about  0.89 seconds
# The symbol  کطبس  mode:  BZCL ,  911  from  952
# It took about  0.77 seconds
# The symbol  کطبس  mode:  BZDL ,  912  from  952
# It took about  0.8 seconds
# The symbol  کفرا  mode:  SSCL ,  913  from  952
#  It took about  0.71 seconds
# The symbol  کفرا  mode:  SSDL ,  914  from  952
#  It took about  0.72 seconds
# The symbol  کفرا  mode:  BZCL ,  915  from  952
# It took about  0.72 seconds
# The symbol  کفرا  mode:  BZDL ,  916  from  952
# The symbol  کفپارس  mode:  SSCL ,  917  from  952
#  It took about  0.87 seconds
# The symbol  کفپارس  mode:  SSDL ,  918  from  952
#  It took about  0.77 seconds
# The symbol  کفپارس  mode:  BZCL ,  919  from  952
# It took about  0.72 seconds
# The symbol  کفپارس  mode:  BZDL ,  920  from  952
# The symbol  کلوند  mode:  SSCL ,  921  from  952
# The symbol  کلوند  mode:  SSDL ,  922  from  952
# The symbol  کلوند  mode:  BZCL ,  923  from  952
# The symbol  کلوند  mode:  BZDL ,  924  from  952
# The symbol  کماسه  mode:  SSCL ,  925  from  952
#  It took about  0.97 seconds
# The symbol  کماسه  mode:  SSDL ,  926  from  952
#  It took about  0.78 seconds
# The symbol  کماسه  mode:  BZCL ,  927  from  952
# It took about  0.85 seconds
# The symbol  کماسه  mode:  BZDL ,  928  from  952
# The symbol  کمنگنز  mode:  SSCL ,  929  from  952
#  It took about  0.82 seconds
# The symbol  کمنگنز  mode:  SSDL ,  930  from  952
#  It took about  0.83 seconds
# The symbol  کمنگنز  mode:  BZCL ,  931  from  952
# It took about  0.71 seconds
# The symbol  کمنگنز  mode:  BZDL ,  932  from  952
# It took about  0.83 seconds
# The symbol  کهمدا  mode:  SSCL ,  933  from  952
#  It took about  0.87 seconds
# The symbol  کهمدا  mode:  SSDL ,  934  from  952
#  It took about  0.73 seconds
# The symbol  کهمدا  mode:  BZCL ,  935  from  952
# It took about  0.92 seconds
# The symbol  کهمدا  mode:  BZDL ,  936  from  952
# It took about  0.72 seconds
# The symbol  کپشیر  mode:  SSCL ,  937  from  952
# The symbol  کپشیر  mode:  SSDL ,  938  from  952
# The symbol  کپشیر  mode:  BZCL ,  939  from  952
# The symbol  کپشیر  mode:  BZDL ,  940  from  952
# The symbol  کچاد  mode:  SSCL ,  941  from  952
#  It took about  0.82 seconds
# The symbol  کچاد  mode:  SSDL ,  942  from  952
#  It took about  0.72 seconds
# The symbol  کچاد  mode:  BZCL ,  943  from  952
# It took about  0.85 seconds
# The symbol  کچاد  mode:  BZDL ,  944  from  952
# It took about  0.71 seconds
# The symbol  کگاز  mode:  SSCL ,  945  from  952
# The symbol  کگاز  mode:  SSDL ,  946  from  952
# The symbol  کگاز  mode:  BZCL ,  947  from  952
# The symbol  کگاز  mode:  BZDL ,  948  from  952
# The symbol  کگل  mode:  SSCL ,  949  from  952
#  It took about  0.89 seconds
# The symbol  کگل  mode:  SSDL ,  950  from  952
#  It took about  0.76 seconds
# The symbol  کگل  mode:  BZCL ,  951  from  952
# It took about  0.83 seconds
# The symbol  کگل  mode:  BZDL ,  952  from  952
# It took about  0.77 seconds
#
#
# **About  952  out of  952  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  238  and output size is:  238
