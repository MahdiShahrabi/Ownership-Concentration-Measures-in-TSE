# %%
import os
from tell_time import tell_time
import pytz
from find_measures import find_measures

# %%
path = r"C:\Users\Mahdi\OneDrive\Master Thesis\Data\MonthlyShareholder"
os.chdir(path)
ls = os.listdir()

# %%
for year in range(1387,1399):
    
    for month in range(1,13):
        
        tell_time('**Year '+str(year)+'|'+str(month)+' has Started!***')
        print('\n')
        
        if "Measures"+str(year)+'_'+str(month)+".csv" not in ls or True:            
            try:                
                find_measures(year=year,month=month,pnt=False)
                print('\n\n')                    
            except:
                pass
# Out:
# **Year 1387|1 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|2 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|3 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|4 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|5 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|6 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|7 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|8 has Started!***
# Current time is:  12:29:33
#
#
# **Year 1387|9 has Started!***
# Current time is:  12:29:33
#
#
# Number of observed firms in year  1387  is :  235
# C:\Users\Mahdi\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\Mahdi\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  235  and output size is:  235
#
#
#
# **Year 1387|10 has Started!***
# Current time is:  12:29:36
#
#
# Number of observed firms in year  1387  is :  235
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  235  and output size is:  235
#
#
#
# **Year 1387|11 has Started!***
# Current time is:  12:29:39
#
#
# Number of observed firms in year  1387  is :  237
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  237  and output size is:  237
#
#
#
# **Year 1387|12 has Started!***
# Current time is:  12:29:42
#
#
# Number of observed firms in year  1387  is :  238
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  238  and output size is:  238
#
#
#
# **Year 1388|1 has Started!***
# Current time is:  12:29:46
#
#
# Number of observed firms in year  1388  is :  238
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  238  and output size is:  238
#
#
#
# **Year 1388|2 has Started!***
# Current time is:  12:29:49
#
#
# Number of observed firms in year  1388  is :  238
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  238  and output size is:  238
#
#
#
# **Year 1388|3 has Started!***
# Current time is:  12:29:52
#
#
# Number of observed firms in year  1388  is :  238
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  238  and output size is:  238
#
#
#
# **Year 1388|4 has Started!***
# Current time is:  12:29:55
#
#
# Number of observed firms in year  1388  is :  239
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  239  and output size is:  239
#
#
#
# **Year 1388|5 has Started!***
# Current time is:  12:29:59
#
#
# Number of observed firms in year  1388  is :  237
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  237  and output size is:  237
#
#
#
# **Year 1388|6 has Started!***
# Current time is:  12:30:02
#
#
# Number of observed firms in year  1388  is :  237
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  237  and output size is:  237
#
#
#
# **Year 1388|7 has Started!***
# Current time is:  12:30:05
#
#
# Number of observed firms in year  1388  is :  239
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  239  and output size is:  239
#
#
#
# **Year 1388|8 has Started!***
# Current time is:  12:30:09
#
#
# Number of observed firms in year  1388  is :  240
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  240  and output size is:  240
#
#
#
# **Year 1388|9 has Started!***
# Current time is:  12:30:12
#
#
# Number of observed firms in year  1388  is :  239
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  239  and output size is:  239
#
#
#
# **Year 1388|10 has Started!***
# Current time is:  12:30:15
#
#
# Number of observed firms in year  1388  is :  240
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  240  and output size is:  240
#
#
#
# **Year 1388|11 has Started!***
# Current time is:  12:30:19
#
#
# Number of observed firms in year  1388  is :  242
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  242  and output size is:  242
#
#
#
# **Year 1388|12 has Started!***
# Current time is:  12:30:22
#
#
# Number of observed firms in year  1388  is :  242
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  242  and output size is:  242
#
#
#
# **Year 1389|1 has Started!***
# Current time is:  12:30:25
#
#
# Number of observed firms in year  1389  is :  244
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  244  and output size is:  244
#
#
#
# **Year 1389|2 has Started!***
# Current time is:  12:30:28
#
#
# Number of observed firms in year  1389  is :  246
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  246  and output size is:  246
#
#
#
# **Year 1389|3 has Started!***
# Current time is:  12:30:32
#
#
# Number of observed firms in year  1389  is :  248
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  248  and output size is:  248
#
#
#
# **Year 1389|4 has Started!***
# Current time is:  12:30:35
#
#
# Number of observed firms in year  1389  is :  249
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  249  and output size is:  249
#
#
#
# **Year 1389|5 has Started!***
# Current time is:  12:30:38
#
#
# Number of observed firms in year  1389  is :  245
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  245  and output size is:  245
#
#
#
# **Year 1389|6 has Started!***
# Current time is:  12:30:42
#
#
# Number of observed firms in year  1389  is :  246
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  246  and output size is:  246
#
#
#
# **Year 1389|7 has Started!***
# Current time is:  12:30:45
#
#
# Number of observed firms in year  1389  is :  246
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  246  and output size is:  246
#
#
#
# **Year 1389|8 has Started!***
# Current time is:  12:30:48
#
#
# Number of observed firms in year  1389  is :  253
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  253  and output size is:  253
#
#
#
# **Year 1389|9 has Started!***
# Current time is:  12:30:52
#
#
# Number of observed firms in year  1389  is :  255
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  255  and output size is:  255
#
#
#
# **Year 1389|10 has Started!***
# Current time is:  12:30:55
#
#
# Number of observed firms in year  1389  is :  260
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  260  and output size is:  260
#
#
#
# **Year 1389|11 has Started!***
# Current time is:  12:30:59
#
#
# Number of observed firms in year  1389  is :  262
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  262  and output size is:  262
#
#
#
# **Year 1389|12 has Started!***
# Current time is:  12:31:02
#
#
# Number of observed firms in year  1389  is :  264
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  264  and output size is:  264
#
#
#
# **Year 1390|1 has Started!***
# Current time is:  12:31:06
#
#
# Number of observed firms in year  1390  is :  264
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  264  and output size is:  264
#
#
#
# **Year 1390|2 has Started!***
# Current time is:  12:31:10
#
#
# Number of observed firms in year  1390  is :  268
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  268  and output size is:  268
#
#
#
# **Year 1390|3 has Started!***
# Current time is:  12:32:19
#
#
# Number of observed firms in year  1390  is :  269
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  269  and output size is:  269
#
#
#
# **Year 1390|4 has Started!***
# Current time is:  12:33:29
#
#
# Number of observed firms in year  1390  is :  274
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  274  and output size is:  274
#
#
#
# **Year 1390|5 has Started!***
# Current time is:  12:34:39
#
#
# Number of observed firms in year  1390  is :  277
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  277  and output size is:  277
#
#
#
# **Year 1390|6 has Started!***
# Current time is:  12:34:43
#
#
# Number of observed firms in year  1390  is :  278
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  278  and output size is:  278
#
#
#
# **Year 1390|7 has Started!***
# Current time is:  12:35:53
#
#
# Number of observed firms in year  1390  is :  281
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  281  and output size is:  281
#
#
#
# **Year 1390|8 has Started!***
# Current time is:  12:37:02
#
#
# Number of observed firms in year  1390  is :  277
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  277  and output size is:  277
#
#
#
# **Year 1390|9 has Started!***
# Current time is:  12:37:06
#
#
# Number of observed firms in year  1390  is :  276
# RE-FILL!
#
#
# **About  0  out of  0  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  276  and output size is:  276
#
#
#
# **Year 1390|10 has Started!***
# Current time is:  12:37:10
#
#
# Number of observed firms in year  1390  is :  278
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  278  and output size is:  278
#
#
#
# **Year 1390|11 has Started!***
# Current time is:  12:38:19
#
#
# Number of observed firms in year  1390  is :  280
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  280  and output size is:  280
#
#
#
# **Year 1390|12 has Started!***
# Current time is:  12:39:29
#
#
# Number of observed firms in year  1390  is :  282
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  282  and output size is:  282
#
#
#
# **Year 1391|1 has Started!***
# Current time is:  12:40:41
#
#
# Number of observed firms in year  1391  is :  282
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  282  and output size is:  282
#
#
#
# **Year 1391|2 has Started!***
# Current time is:  12:41:51
#
#
# Number of observed firms in year  1391  is :  286
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  286  and output size is:  286
#
#
#
# **Year 1391|3 has Started!***
# Current time is:  12:43:01
#
#
# Number of observed firms in year  1391  is :  288
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  288  and output size is:  288
#
#
#
# **Year 1391|4 has Started!***
# Current time is:  12:45:17
#
#
# Number of observed firms in year  1391  is :  286
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  286  and output size is:  286
#
#
#
# **Year 1391|5 has Started!***
# Current time is:  12:47:33
#
#
# Number of observed firms in year  1391  is :  285
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  285  and output size is:  285
#
#
#
# **Year 1391|6 has Started!***
# Current time is:  12:48:44
#
#
# Number of observed firms in year  1391  is :  288
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  288  and output size is:  288
#
#
#
# **Year 1391|7 has Started!***
# Current time is:  12:51:01
#
#
# Number of observed firms in year  1391  is :  292
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  292  and output size is:  292
#
#
#
# **Year 1391|8 has Started!***
# Current time is:  12:52:12
#
#
# Number of observed firms in year  1391  is :  292
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  292  and output size is:  292
#
#
#
# **Year 1391|9 has Started!***
# Current time is:  12:54:28
#
#
# Number of observed firms in year  1391  is :  293
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  293  and output size is:  293
#
#
#
# **Year 1391|10 has Started!***
# Current time is:  12:56:44
#
#
# Number of observed firms in year  1391  is :  293
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  293  and output size is:  293
#
#
#
# **Year 1391|11 has Started!***
# Current time is:  12:59:01
#
#
# Number of observed firms in year  1391  is :  295
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  295  and output size is:  295
#
#
#
# **Year 1391|12 has Started!***
# Current time is:  13:01:17
#
#
# Number of observed firms in year  1391  is :  301
# RE-FILL!
#
#
# **About  0  out of  1  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  301  and output size is:  301
#
#
#
# **Year 1392|1 has Started!***
# Current time is:  13:02:28
#
#
# Number of observed firms in year  1392  is :  302
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  302  and output size is:  302
#
#
#
# **Year 1392|2 has Started!***
# Current time is:  13:04:44
#
#
# Number of observed firms in year  1392  is :  301
# RE-FILL!
#
#
# **About  10  out of  13  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  301  and output size is:  301
#
#
#
# **Year 1392|3 has Started!***
# Current time is:  13:11:00
#
#
# Number of observed firms in year  1392  is :  302
# RE-FILL!
#
#
# **About  12  out of  14  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  302  and output size is:  302
#
#
#
# **Year 1392|4 has Started!***
# Current time is:  13:15:42
#
#
# Number of observed firms in year  1392  is :  304
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  304  and output size is:  304
#
#
#
# **Year 1392|5 has Started!***
# Current time is:  13:18:00
#
#
# Number of observed firms in year  1392  is :  300
# RE-FILL!
#
#
# **About  6  out of  8  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  300  and output size is:  300
#
#
#
# **Year 1392|6 has Started!***
# Current time is:  13:22:06
#
#
# Number of observed firms in year  1392  is :  302
# RE-FILL!
#
#
# **About  5  out of  6  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  302  and output size is:  302
#
#
#
# **Year 1392|7 has Started!***
# Current time is:  13:25:18
#
#
# Number of observed firms in year  1392  is :  301
# RE-FILL!
#
#
# **About  3  out of  6  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  301  and output size is:  301
#
#
#
# **Year 1392|8 has Started!***
# Current time is:  13:28:28
#
#
# Number of observed firms in year  1392  is :  293
# RE-FILL!
#
#
# **About  7  out of  8  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  293  and output size is:  293
#
#
#
# **Year 1392|9 has Started!***
# Current time is:  13:30:44
#
#
# Number of observed firms in year  1392  is :  235
# RE-FILL!
#
#
# **About  6  out of  7  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  235  and output size is:  235
#
#
#
# **Year 1392|10 has Started!***
# Current time is:  13:32:29
#
#
# Number of observed firms in year  1392  is :  311
# RE-FILL!
#
#
# **About  7  out of  8  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  311  and output size is:  311
#
#
#
# **Year 1392|11 has Started!***
# Current time is:  13:35:13
#
#
# Number of observed firms in year  1392  is :  304
# RE-FILL!
#
#
# **About  8  out of  9  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  304  and output size is:  304
#
#
#
# **Year 1392|12 has Started!***
# Current time is:  13:38:11
#
#
# Number of observed firms in year  1392  is :  308
# RE-FILL!
#
#
# **About  0  out of  3  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  308  and output size is:  308
#
#
#
# **Year 1393|1 has Started!***
# Current time is:  13:41:34
#
#
# Number of observed firms in year  1393  is :  326
# RE-FILL!
#
#
# **About  12  out of  14  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  326  and output size is:  326
#
#
#
# **Year 1393|2 has Started!***
# Current time is:  13:46:31
#
#
# Number of observed firms in year  1393  is :  326
# RE-FILL!
#
#
# **About  4  out of  7  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  326  and output size is:  326
#
#
#
# **Year 1393|3 has Started!***
# Current time is:  13:50:59
#
#
# Number of observed firms in year  1393  is :  328
# RE-FILL!
#
#
# **About  4  out of  7  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  328  and output size is:  328
#
#
#
# **Year 1393|4 has Started!***
# Current time is:  13:55:01
#
#
# Number of observed firms in year  1393  is :  327
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  327  and output size is:  327
#
#
#
# **Year 1393|5 has Started!***
# Current time is:  13:57:18
#
#
# Number of observed firms in year  1393  is :  325
# RE-FILL!
#
#
# **About  9  out of  12  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  325  and output size is:  325
#
#
#
# **Year 1393|6 has Started!***
# Current time is:  14:02:20
#
#
# Number of observed firms in year  1393  is :  328
# RE-FILL!
#
#
# **About  7  out of  9  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  328  and output size is:  328
#
#
#
# **Year 1393|7 has Started!***
# Current time is:  14:06:19
#
#
# Number of observed firms in year  1393  is :  325
# RE-FILL!
#
#
# **About  5  out of  6  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  325  and output size is:  325
#
#
#
# **Year 1393|8 has Started!***
# Current time is:  14:08:01
#
#
# Number of observed firms in year  1393  is :  330
# RE-FILL!
#
#
# **About  8  out of  11  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  330  and output size is:  330
#
#
#
# **Year 1393|9 has Started!***
# Current time is:  14:12:39
#
#
# Number of observed firms in year  1393  is :  338
# RE-FILL!
#
#
# **About  12  out of  13  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  338  and output size is:  338
#
#
#
# **Year 1393|10 has Started!***
# Current time is:  14:15:40
#
#
# Number of observed firms in year  1393  is :  346
# RE-FILL!
#
#
# **About  5  out of  8  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  346  and output size is:  346
#
#
#
# **Year 1393|11 has Started!***
# Current time is:  14:20:03
#
#
# Number of observed firms in year  1393  is :  337
# RE-FILL!
#
#
# **About  3  out of  6  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  337  and output size is:  337
#
#
#
# **Year 1393|12 has Started!***
# Current time is:  14:23:43
#
#
# Number of observed firms in year  1393  is :  349
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  349  and output size is:  349
#
#
#
# **Year 1394|1 has Started!***
# Current time is:  14:26:00
#
#
# Number of observed firms in year  1394  is :  354
# RE-FILL!
#
#
# **About  5  out of  9  of mising cells are filled!
# len(Errors):  4
# Orginal Size is  354  and output size is:  354
#
#
#
# **Year 1394|2 has Started!***
# Current time is:  14:30:14
#
#
# Number of observed firms in year  1394  is :  354
# RE-FILL!
#
#
# **About  7  out of  7  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  354  and output size is:  354
#
#
#
# **Year 1394|3 has Started!***
# Current time is:  14:31:49
#
#
# Number of observed firms in year  1394  is :  357
# RE-FILL!
#
#
# **About  8  out of  8  of mising cells are filled!
# len(Errors):  0
# Orginal Size is  357  and output size is:  357
#
#
#
# **Year 1394|4 has Started!***
# Current time is:  14:33:21
#
#
# Number of observed firms in year  1394  is :  356
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  356  and output size is:  356
#
#
#
# **Year 1394|5 has Started!***
# Current time is:  14:35:38
#
#
# Number of observed firms in year  1394  is :  362
# RE-FILL!
#
#
# **About  66  out of  67  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  362  and output size is:  362
#
#
#
# **Year 1394|6 has Started!***
# Current time is:  14:51:34
#
#
# Number of observed firms in year  1394  is :  368
# RE-FILL!
#
#
# **About  54  out of  55  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  368  and output size is:  368
#
#
#
# **Year 1394|7 has Started!***
# Current time is:  15:03:43
#
#
# Number of observed firms in year  1394  is :  367
# RE-FILL!
#
#
# **About  47  out of  48  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  367  and output size is:  367
#
#
#
# **Year 1394|8 has Started!***
# Current time is:  15:13:43
#
#
# Number of observed firms in year  1394  is :  371
# RE-FILL!
#
#
# **About  50  out of  51  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  371  and output size is:  371
#
#
#
# **Year 1394|9 has Started!***
# Current time is:  15:23:42
#
#
# Number of observed firms in year  1394  is :  372
# RE-FILL!
#
#
# **About  43  out of  44  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  372  and output size is:  372
#
#
#
# **Year 1394|10 has Started!***
# Current time is:  15:32:38
#
#
# Number of observed firms in year  1394  is :  364
# RE-FILL!
#
#
# **About  49  out of  50  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  364  and output size is:  364
#
#
#
# **Year 1394|11 has Started!***
# Current time is:  15:41:44
#
#
# Number of observed firms in year  1394  is :  360
# RE-FILL!
#
#
# **About  58  out of  59  of mising cells are filled!
# len(Errors):  1
# Orginal Size is  360  and output size is:  360
#
#
#
# **Year 1394|12 has Started!***
# Current time is:  15:51:51
#
#
# Number of observed firms in year  1394  is :  362
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  362  and output size is:  362
#
#
#
# **Year 1395|1 has Started!***
# Current time is:  15:54:08
#
#
# Number of observed firms in year  1395  is :  371
# RE-FILL!
#
#
# **About  63  out of  65  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  371  and output size is:  371
#
#
#
# **Year 1395|2 has Started!***
# Current time is:  16:06:51
#
#
# Number of observed firms in year  1395  is :  382
# RE-FILL!
#
#
# **About  55  out of  57  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  382  and output size is:  382
#
#
#
# **Year 1395|3 has Started!***
# Current time is:  16:16:43
#
#
# Number of observed firms in year  1395  is :  384
# RE-FILL!
#
#
# **About  60  out of  62  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  384  and output size is:  384
#
#
#
# **Year 1395|4 has Started!***
# Current time is:  16:23:03
#
#
# Number of observed firms in year  1395  is :  391
# RE-FILL!
#
#
# **About  1  out of  3  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  391  and output size is:  391
#
#
#
# **Year 1395|5 has Started!***
# Current time is:  16:25:50
#
#
# Number of observed firms in year  1395  is :  384
# RE-FILL!
#
#
# **About  47  out of  49  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  384  and output size is:  384
#
#
#
# **Year 1395|6 has Started!***
# Current time is:  16:30:16
#
#
# Number of observed firms in year  1395  is :  382
# RE-FILL!
#
#
# **About  46  out of  48  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  382  and output size is:  382
#
#
#
# **Year 1395|7 has Started!***
# Current time is:  16:34:33
#
#
# Number of observed firms in year  1395  is :  378
# RE-FILL!
#
#
# **About  55  out of  57  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  378  and output size is:  378
#
#
#
# **Year 1395|8 has Started!***
# Current time is:  16:39:01
#
#
# Number of observed firms in year  1395  is :  397
# RE-FILL!
#
#
# **About  58  out of  63  of mising cells are filled!
# len(Errors):  5
# Orginal Size is  397  and output size is:  397
#
#
#
# **Year 1395|9 has Started!***
# Current time is:  16:46:00
#
#
# Number of observed firms in year  1395  is :  406
# RE-FILL!
#
#
# **About  84  out of  87  of mising cells are filled!
# len(Errors):  3
# Orginal Size is  406  and output size is:  406
#
#
#
# **Year 1395|10 has Started!***
# Current time is:  16:53:20
#
#
# Number of observed firms in year  1395  is :  409
# RE-FILL!
#
#
# **About  51  out of  56  of mising cells are filled!
# len(Errors):  5
# Orginal Size is  409  and output size is:  409
#
#
#
# **Year 1395|11 has Started!***
# Current time is:  17:01:43
#
#
# Number of observed firms in year  1395  is :  413
# RE-FILL!
#
#
# **About  23  out of  28  of mising cells are filled!
# len(Errors):  5
# Orginal Size is  413  and output size is:  413
#
#
#
# **Year 1395|12 has Started!***
# Current time is:  17:08:37
#
#
# Number of observed firms in year  1395  is :  413
# RE-FILL!
#
#
# **About  0  out of  2  of mising cells are filled!
# len(Errors):  2
# Orginal Size is  413  and output size is:  413
#
#
#
# **Year 1396|1 has Started!***
# Current time is:  17:10:56
#
#
# Number of observed firms in year  1396  is :  555
# RE-FILL!
#
#
# **About  71  out of  80  of mising cells are filled!
# len(Errors):  9
# Orginal Size is  555  and output size is:  555
#
#
#
# **Year 1396|2 has Started!***
# Current time is:  17:26:50
#
#
# Number of observed firms in year  1396  is :  558
# RE-FILL!
#
#
# **About  69  out of  78  of mising cells are filled!
# len(Errors):  9
# Orginal Size is  558  and output size is:  558
#
#
#
# **Year 1396|3 has Started!***
# Current time is:  17:41:59
#
#
# Number of observed firms in year  1396  is :  561
# RE-FILL!
#
#
# **About  51  out of  59  of mising cells are filled!
# len(Errors):  8
# Orginal Size is  561  and output size is:  561
#
#
#
# **Year 1396|4 has Started!***
# Current time is:  17:54:52
#
#
# Number of observed firms in year  1396  is :  564
# RE-FILL!
#
#
# **About  0  out of  10  of mising cells are filled!
# len(Errors):  10
# Orginal Size is  564  and output size is:  564
#
#
#
# **Year 1396|5 has Started!***
# Current time is:  18:05:59
#
#
# Number of observed firms in year  1396  is :  566
# RE-FILL!
#
#
# **About  62  out of  73  of mising cells are filled!
# len(Errors):  11
# Orginal Size is  566  and output size is:  566
#
#
#
# **Year 1396|6 has Started!***
# Current time is:  18:24:41
#
#
# Number of observed firms in year  1396  is :  571
# RE-FILL!

# %%
jkj
