# %%
## Loading Libraries
import pandas as pd
import numpy as np
import sys
import jdatetime as jd
import os
import pickle
import io

# import power_index_calculator as px
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from ReadingBalancesheetData import read_blnc_data
from ReadingIncomeData import read_inc_data
from ReadingCashFlowData import read_cf_data
from convert_ar_characters import convert_ar_characters

# %% [markdown]
# # Creating شرکت-نماد dict from Balance Sheet Data

# %%
## Updating Sh_spec_handy based on the شرکت-نماد for years 1397-8 from balance sheet data
# Loading Sh_spec_handy data
os.chdir(r"C:\Users\Mahdi\Dr. Heidari - TSE\WorkInHands\_Data\OtherData")
Sh_spec_handy=pd.read_excel("Sh_spec_handy.xlsx")
Sh_spec_handy.Shareholder_raw=Sh_spec_handy.Shareholder_raw.apply(lambda x: convert_ar_characters(x))
Sh_spec_handy.Shareholder=Sh_spec_handy.Shareholder.apply(lambda x: convert_ar_characters(x))

# Loading data and convert names
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
df95 = pd.read_excel('95.xlsx')
df95['شرکت']=df95['شرکت'].apply(lambda x: convert_ar_characters(x))

df96 = pd.read_excel('95.xlsx')
df96['شرکت']=df96['شرکت'].apply(lambda x: convert_ar_characters(x))

with open('97.txt',encoding="utf8") as f:
    fileobject = io.StringIO(f.read())
df97 = pd.read_csv(fileobject, sep='\t',  lineterminator='\n', names=None)
df97['شرکت']=df97['شرکت'].apply(lambda x: convert_ar_characters(x))
df97['نماد']=df97['نماد'].apply(lambda x: convert_ar_characters(x))

with open('98.txt',encoding="utf8") as f:
    fileobject = io.StringIO(f.read())
df98 = pd.read_csv(fileobject, sep='\t',  lineterminator='\n', names=None)
df98['شرکت']=df98['شرکت'].apply(lambda x: convert_ar_characters(x))
df98['نماد']=df98['نماد'].apply(lambda x: convert_ar_characters(x))

# Appending the data of two years
sherkat_namad = df97[['شرکت','نماد']].append(df98[['شرکت','نماد']]).drop_duplicates()
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['سر. صنعت و معدن'],
                         'نماد':['وصنعت']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['مهندسی فیروزا'],
                         'نماد':['تفیرو']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['تامین مواد اولیه فولاد صبانور'],
                         'نماد':['کنور']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['پتروشیمی فجر'],
                         'نماد':['بفجر']}))
sherkat_namad.rename(columns={'شرکت':'Shareholder_raw','نماد':'Shareholder'},inplace=True)
sherkat_namad = sherkat_namad.drop_duplicates()

# Updating the Sh_spec_handy file
Sh_spec_handy = Sh_spec_handy.append(sherkat_namad).drop_duplicates()
Sh_spec_handy = Sh_spec_handy[Sh_spec_handy.Shareholder !='nan']
sherkat_namad_dict = dict(zip(Sh_spec_handy['Shareholder_raw'],Sh_spec_handy['Shareholder']))

# %% [markdown]
# # **Cleaning BalanceSheet Data**

# %%
## Loading Balance sheet DATA
for year in [1395,1396,1397,1398]:
    out_name = "BalanceSheet"+str(year)+".csv"
    df_blnc = read_blnc_data(year=year,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df_blnc['data'].to_csv(out_name)

blnc_dict = pd.DataFrame(data={'نام اصلی':list(df_blnc['columns_dict'].keys()),
                               'نام استفاده شده':list(df_blnc['columns_dict'].values())})    
blnc_dict.to_excel('Blnc_columns_dict.xlsx')

# %%
blnc_dict
df_blnc['data'].head()
# Out:
#                                     نام اصلی       نام استفاده شده
# 0                                       نماد                Symbol
# 1                                       شرکت                  Firm
# 2                                   سال مالی              Fin_year
# 3                        جمع دارایی‌های جاری     Tot_current_asset
# 4                                 تاریخ مصوب          Approve_date
# 5                       خالص دارایی‌های ثابت                   PPE
# 6           سرمایه گذاری‌ها و سایر دارایی‌ها  other_longterm_asset
# 7                          جمع بدهی‌های جاری       Tot_current_lib
# 8                           جمع کل دارایی‌ها             Tot_asset
# 9                    جمع دارایی‌های غیر جاری  Tot_noncurrent_asset
# 10                                    سرمایه               Capital
# 11                                حقوق عمومی         public_rights
# 12                            جمع کل بدهی‌ها               Tot_lib
# 13                     جمع بدهی‌های غیر جاری    Tot_noncurrent_lib
# 14                           سایر اندوخته‌ها          Saving_other
# 15                            اندوخته قانونی       Saving_required
# 16                        سود و زیان انباشته    Acummulated_profit
# 17    جمع حقوق صاحبان سهام در پایان سال مالی                Equity
# 18         جمع کل بدهی‌ها و حقوق صاحبان سهام       Debt_and_equity
# 19  جمع حقوق صاحبان سهام مصوب (در مجمع عادی)    debt_equity_normal
#                  Firm Symbol    Fin_year  Year Approve_date  \
# 0               آ.س.پ  آ س پ  1398-06-31  1397   1398-09-16
# 1            آبادگران  ثاباد  1397-12-29  1397   1398-08-04
# 2  آبادگران ایران کیش   گکیش  1398-06-31  1397   1398-10-23
# 3               آبسال  لابسا  1397-12-29  1397   1398-04-20
# 4                آبفر   آبفر  1385-12-29  1385   1386-04-13
#
#    Tot_current_asset       PPE  other_longterm_asset  Tot_noncurrent_asset  \
# 0          1396143.0   18601.0                2673.0               68886.0
# 1           314503.0    4681.0               33425.0               38394.0
# 2            32964.0   53103.0               11696.0               66086.0
# 3          1636152.0  199260.0               10608.0              211315.0
# 4            41695.0    9627.0                1366.0               10993.0
#
#    Tot_asset  ...    Tot_lib   Capital  Acummulated_profit  Saving_required  \
# 0  1465029.0  ...   518844.0  800000.0             15315.0          30870.0
# 1   352897.0  ...    65412.0  240000.0             31207.0          16278.0
# 2    99050.0  ...    10521.0   64000.0             19695.0           4468.0
# 3  1847467.0  ...  1172248.0  360000.0            254211.0          36000.0
# 4    52688.0  ...    70777.0   16800.0            -35189.0            300.0
#
#    Saving_other    Equity  Debt_and_equity  Book_value  debt_equity_normal  \
# 0           NaN  946185.0        1465029.0    946185.0            946185.0
# 1           NaN  287485.0         352897.0    287485.0                 NaN
# 2         366.0   88529.0          99050.0     88529.0             78929.0
# 3           NaN  675219.0        1847467.0    675219.0            610611.0
# 4           NaN  -18089.0          52688.0    -18089.0                 NaN
#
#    public_rights
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Cleaning Income Statement Data**

# %%
# Reading all data and appending
all_inc = pd.DataFrame()
for year in range(1390,1399):
    temp = read_inc_data(year,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)
    all_inc = all_inc.append(temp['data'])

# Creating dict for persian-english column names
Inc_dict = pd.DataFrame(data={'نام اصلی':list(temp['columns_dict'].keys()),'نام استفاده شده':list(temp['columns_dict'].values())})
Inc_dict.to_excel('Inc_columns_dict.xlsx')

# Saving Data
for year in list(all_inc.Year.drop_duplicates()):
    out_name = "IncomeStatement"+str(year)+".csv"
    df_inc = all_inc[all_inc.Year==year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df_inc.to_csv(out_name)

# %%
Inc_dict
df_inc.head()
# Out:
#                                              نام اصلی  \
# 0                                            نام شرکت
# 1                                                نماد
# 2                                            سال مالی
# 3                                          تاریخ مصوب
# 4                                            ارزش روز
# 5                                              سرمایه
# 6                                         جمع درآمدها
# 7                       بهای تمام شده کالای فروش رفته
# 8   هزینه تامین منابع مالی عملیات لیزینگ (هزینه سو...
# 9                                          سود ناویژه
# 10                   خالص درآمدها و هزینه‌های عملیاتی
# 11                                 سود (زیان) عملیاتی
# 12                                     هزینه‌های مالی
# 13              سود (زیان) تسعیر تسهیلات ارزی دریافتی
# 14                       خالص سایر درآمدها (هزینه‌ها)
# 15                 سود(زیان)فروش دارائیهای زیستی مولد
# 16                          تعدیل ارزش سرمایه گذاریها
# 17                       سود (زیان) قبل از کسر مالیات
# 18                                             مالیات
# 19                          سهم اقلیت از سود سال جاری
# 20                        سود (زیان) پس از کسر مالیات
# 21                            سود انباشته ابتدای دوره
# 22                                     تعدیلات سنواتی
# 23                                     سود قابل تخصیص
# 24                                            epsخالص
# 25                                          epsناخالص
# 26                                   نسبت سود به فروش
# 27              بهای تمام شده املاک فروش رفته و خدمات
#
#                     نام استفاده شده
# 0                              Firm
# 1                            Symbol
# 2                          Fin_year
# 3                      Approve_date
# 4                         Marketcap
# 5                           Capital
# 6                           Revenue
# 7                   Cost_of_revenue
# 8                     capital_cost_
# 9                      Gross_profit
# 10               Operating_expenses
# 11                 Operating_income
# 12                         Interest
# 13             exchange_rate_profit
# 14  Total_other_income_expenses_net
# 15                    green_profit_
# 16                 adj_investments_
# 17                              EBT
# 18                              Tax
# 19      minority_share_from_profit_
# 20                       Net_income
# 21                acumulated_profit
# 22                      adjustments
# 23                divideable_profit
# 24                          Net_eps
# 25                             eps_
# 26                   profit_to_sale
# 27              real_estate_income_
#                           Firm Symbol    Fin_year  Year Approve_date  \
# 8                     سر. غدیر  وغدیر  1398-09-30  1398   1399-02-07
# 17                    سر. امید  وامید  1398-10-30  1398   1399-01-31
# 24            سنگ آهن گهر زمین   کگهر  1398-09-30  1398   1399-02-02
# 44         صنایع شیمیایی ایران  شیران  1398-09-30  1398   1398-12-04
# 74  پرداخت الکترونیک سامان کیش     سپ  1398-09-30  1398   1398-12-24
#
#        Revenue  Cost_of_revenue  Gross_profit  Operating_expenses  \
# 8   40839449.0              NaN    40839449.0            281464.0
# 17  34958155.0              NaN    34958155.0            153943.0
# 24  53125195.0       24562171.0    28563024.0            144189.0
# 44  18430522.0       13008511.0     5422011.0            969812.0
# 74  16446448.0       13614112.0     2832336.0                 NaN
#
#     Operating_income  ...  divideable_profit  exchange_rate_profit     ps  \
# 8         40450003.0  ...         50292455.0                   NaN  19.39
# 17        34905373.0  ...                NaN                   NaN  14.80
# 24        25955252.0  ...                NaN                   NaN   8.06
# 44         5749410.0  ...         10950815.0                   NaN  12.07
# 74         2610480.0  ...                NaN                   NaN   7.86
#
#     profit_to_sale    eps_  minority_share_from_profit_  capital_cost_  \
# 8          95.6696   543.0                          NaN            NaN
# 17         92.2323  1075.0                          NaN            NaN
# 24          48.814  2108.0                          NaN            NaN
# 44         57.6555  1317.0                          NaN            NaN
# 74          16.602   910.0                          NaN            NaN
#
#     real_estate_income_  green_profit_  adj_investments_
# 8                   NaN            NaN               NaN
# 17                  NaN            NaN               NaN
# 24                  NaN            NaN               NaN
# 44                  NaN            NaN               NaN
# 74                  NaN            NaN               NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # **Cleaning Dividend Data**

# %%
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
dividend_data = pd.read_excel('Annual_div-98.xlsx')
dividend_data = dividend_data.sort_values(by='year')
dividend_data = dividend_data[dividend_data.year>=1389]
dividend_data['firm'] = dividend_data['firm'].apply(lambda x: convert_ar_characters(x))
dividend_data['symbol'] = dividend_data['firm'].map(sherkat_namad_dict,na_action='ignore')
dividend_data['industry'] = dividend_data['industry'].apply(lambda x: convert_ar_characters(x))
dividend_data.rename(columns={'capital':'Equity','symbol':'Symbol','firm':'Firm','year':'Year','industry':'Industry','ind_id':'Ind_id',
                             'earning':'Earning','dividend':'Dividend','payout':'Payout','eps':'EPS','dps':'DPS'},inplace=True)

dividend_data = dividend_data[['Year', 'Firm', 'Symbol', 'Industry', 'Earning','Dividend','Payout','EPS', 'DPS', 'Equity',
                               'adj_eps', 'adj_dps', 'adj_earning', 'adj_dividend', 'cpi','Ind_id']]

# %%
for year in list(dividend_data.Year.drop_duplicates()):
    out_name = 'Dividend'+str(year)+'.csv'
    df = dividend_data[dividend_data.Year == year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df.to_csv(out_name)

# %%
df.head()
# Out:
#       Year                 Firm Symbol  \
# 2360  1397      ایرکا پارت صنعت   خکار
# 7529  1397  فولاد کاوه جنوب کیش   کاوه
# 7051  1397            البرزدارو  دالبر
# 1884  1397          مهرکام پارس   خمهر
# 4603  1397             بیمه ملت    ملت
#
#                                       Industry     Earning  Dividend  \
# 2360                        خودرو و ساخت قطعات    4.250000      1.00
# 7529                               فلزات اساسی  944.900000    990.00
# 7051                     مواد و محصولات دارویی  151.218000    133.92
# 1884                        خودرو و ساخت قطعات  -43.379229      0.00
# 4603  بیمه وصندوق بازنشستگی به جزتامین اجتماعی   86.070000     71.25
#
#         Payout  EPS  DPS      Equity  adj_eps  adj_dps  adj_earning  \
# 2360  0.235294   85   20    562808.0      NaN      NaN          NaN
# 7529  1.047730  859  900  17018133.0      NaN      NaN          NaN
# 7051  0.885609  813  720   3920279.0      NaN      NaN          NaN
# 1884       NaN -233    0   1014661.0      NaN      NaN          NaN
# 4603  0.827815  302  250   4507619.0      NaN      NaN          NaN
#
#       adj_dividend  cpi  Ind_id
# 2360           NaN  NaN      34
# 7529           NaN  NaN      27
# 7051           NaN  NaN      43
# 1884           NaN  NaN      34
# 4603           NaN  NaN      66

# %% [markdown]
# # **Cleaning Cash Flow Statement Data**

# %%
path = r"C:\Users\Mahdi\OneDrive\Master Thesis\Data"
for year in range(1389,1399):
    out_name_short = 'CashFlow'+str(year)+'.csv'
    out_name_all = 'CashFlow'+str(year)+'_all.csv'
    df = read_cf_data(year=year,path=path,sherkat_namad_dict=sherkat_namad_dict)
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df['data_short'].to_csv(out_name_short)
    df['data_all'].to_csv(out_name_all)

CF_dict = pd.DataFrame(data={'نام اصلی':list(df['columns_dict'].keys()),'نام استفاده شده':list(df['columns_dict'].values())})
CF_dict.to_excel('CF_columns_dict.xlsx')

# %%
df['data_short'].head()
# Out:
#    Year                Firm Symbol    Fin_year Approve_date  \
# 0  1397               آ.س.پ  آ س پ  1398-06-31   1398-08-19
# 1  1397            آبادگران  ثاباد  1397-12-29   1398-03-25
# 2  1397  آبادگران ایران کیش   گکیش  1398-06-31   1398-10-04
# 3  1397               آبسال  لابسا  1397-12-29   1398-04-09
# 5  1393              آبگینه  کابگن  1393-12-29   1394-04-21
#
#    Operating_cash_flow  Investing_cash_flow  Financing_cash_flow  \
# 0               5920.0               4140.0              25519.0
# 1               7729.0               1948.0              -7622.0
# 2              10821.0             -12621.0                  NaN
# 3             516841.0             -27639.0            -290492.0
# 5             -55479.0               3033.0              54168.0
#
#    Begining_cash_position  Change_in_cash  End_cash_position
# 0                  1910.0         25708.0            27618.0
# 1                   296.0           118.0              414.0
# 2                  1264.0            95.0             1359.0
# 3                 27804.0         81253.0           116515.0
# 5                  2570.0          -921.0             1568.0
