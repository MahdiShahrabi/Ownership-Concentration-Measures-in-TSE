# %%
## Loading Libraries
import pandas as pd
import numpy as np
import sys
import jdatetime as jd
import os
import pickle
import io

# import power_index_calculator as px
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from ReadingBalancesheetData import read_blnc_data
from ReadingIncomeData import read_inc_data
from ReadingCashFlowData import read_cf_data
from convert_ar_characters import convert_ar_characters
from functions import find_year

# %% [markdown]
# # Creating شرکت-نماد dict from Balance Sheet Data

# %%
## Updating Sh_spec_handy based on the شرکت-نماد for years 1397-8 from balance sheet data
# Loading Sh_spec_handy data
os.chdir(r"C:\Users\Mahdi\Dr. Heidari - TSE\WorkInHands\_Data\OtherData")
Sh_spec_handy=pd.read_excel("Sh_spec_handy.xlsx")
Sh_spec_handy.Shareholder_raw=Sh_spec_handy.Shareholder_raw.apply(lambda x: convert_ar_characters(x))
Sh_spec_handy.Shareholder=Sh_spec_handy.Shareholder.apply(lambda x: convert_ar_characters(x))

os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
sherkat_namad = pd.DataFrame()
for year in range(1385,1399):
    file_name = 'BS'+str(year)[2:]+'.csv'
    df = pd.read_csv(file_name,header=1)
    df['شرکت']=df['شرکت'].apply(lambda x: convert_ar_characters(x))
    df['نماد']=df['نماد'].apply(lambda x: convert_ar_characters(x))
    sherkat_namad = sherkat_namad.append(df[['شرکت','نماد']]).drop_duplicates()
    
# Appending the data of two years
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['سر. صنعت و معدن'],'نماد':['وصنعت']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['مهندسی فیروزا'],'نماد':['تفیرو']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['تامین مواد اولیه فولاد صبانور'],'نماد':['کنور']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['پتروشیمی فجر'],'نماد':['بفجر']}))
sherkat_namad = sherkat_namad.append(pd.DataFrame(data={'شرکت':['پتروشیمی مبین'],'نماد':['مبین']}))

sherkat_namad.rename(columns={'شرکت':'Shareholder_raw','نماد':'Shareholder'},inplace=True)
sherkat_namad = sherkat_namad.drop_duplicates()

# Updating the Sh_spec_handy file
Sh_spec_handy = Sh_spec_handy.append(sherkat_namad).drop_duplicates()
Sh_spec_handy = Sh_spec_handy[Sh_spec_handy.Shareholder !='nan']
sherkat_namad_dict = dict(zip(Sh_spec_handy['Shareholder_raw'],Sh_spec_handy['Shareholder']))

# %% [markdown]
# # **Cleaning BalanceSheet Data**

# %%
# ## We did not have enough data for 1398. So in this cell we want to see what is happening?!
# temp = read_blnc_data(year=1398,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)['data']
# temp['year'] = temp.Fin_year.apply(lambda x: x.year)
# temp98 = temp[temp.year==1398]
# mf = pd.read_csv('Measures1398.csv',index_col=0).drop_duplicates()

# print('Number of Symbols in BS98: ',len(temp.Symbol.drop_duplicates()))
# temp.groupby('year')['Symbol'].agg('count').iloc[-5:]
# print('Number of Symbols in BS98 in the year 1398 and before month 6: ',len(temp98[temp98.Year==1397]))
# temp98.groupby('Fin_year')['Symbol'].agg('count')
# print('Number of comoon Symbols in BS98 and Measure 98 in the year 1398: ',len(set(mf.Symbol).intersection(set(temp98.Symbol))))
# print('Number of Symbols in Measure 98 before filtration: ',len(mf))

# %%
df = pd.DataFrame()
for year in range(1385,1399):
    temp = read_blnc_data(year=year,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)
    temp['data']['year_id'] = year
    df = df.append(temp['data'])
    
blnc_dict = pd.DataFrame(data={'نام اصلی':list(temp['columns_dict'].keys()),'نام استفاده شده':list(temp['columns_dict'].values())})    
blnc_dict.to_excel('Blnc_columns_dict.xlsx')

df = df[df.Year>=1385]
df = df.drop_duplicates([x for x in list(df.columns) if x is not 'year_id'])
df['year'] = df.Fin_year.apply(lambda x: x.year)

# Handling observations for the same year from different years!
dupped = df[df.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
un_dupped = df[~df.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
firm_sym_dict =dict(zip(dupped.Firm,dupped.Symbol))
dupped = dupped.groupby(['Symbol','Year'],as_index=False).ffill().reindex(dupped.columns, axis=1)
dupped['Symbol'] = dupped.Firm.map(sherkat_namad_dict)
dupped['Year'] = dupped.Fin_year.apply(lambda x: find_year(x))
dupped = dupped.sort_values(by=['Symbol','Year'])
dupped = dupped.drop_duplicates(['Symbol','Year'],keep='last')
df = dupped.append(un_dupped).sort_values(by=['Symbol','Year'])

## Loading Balance sheet DATA
for year in range(1385,1399):
    out_name = "BalanceSheet"+str(year)+".csv"
    df_blnc = df[df.Year==year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df_blnc.to_csv(out_name)

# %%
blnc_dict
df.groupby('Year')['Symbol'].agg('count')
df_blnc.head()
# Out:
#                                     نام اصلی       نام استفاده شده
# 0                                       نماد                Symbol
# 1                                       شرکت                  Firm
# 2                                   سال مالی              Fin_year
# 3                        جمع دارایی‌های جاری     Tot_current_asset
# 4                                 تاریخ مصوب          Approve_date
# 5                       خالص دارایی‌های ثابت                   PPE
# 6           سرمایه گذاری‌ها و سایر دارایی‌ها  other_longterm_asset
# 7                          جمع بدهی‌های جاری       Tot_current_lib
# 8                           جمع کل دارایی‌ها             Tot_asset
# 9                    جمع دارایی‌های غیر جاری  Tot_noncurrent_asset
# 10                                    سرمایه               Capital
# 11                                حقوق عمومی         public_rights
# 12                            جمع کل بدهی‌ها               Tot_lib
# ...

# %% [markdown]
# # **Cleaning Income Statement Data**

# %%
# ## We did not have enough data for 1398. So in this cell we want to see what is happening?!
# len(pd.read_csv('inc98.csv'))
# temp = read_inc_data(year=1398,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)['data']
# temp['year'] = temp.Fin_year.apply(lambda x: x.year)
# temp98 = temp[temp.year==1398]
# mf = pd.read_csv('Measures1398.csv',index_col=0).drop_duplicates()

# print('Number of Symbols in BS98: ',len(temp.Symbol.drop_duplicates()))
# temp.groupby('year')['Symbol'].agg('count').iloc[-5:]
# print('Number of Symbols in BS98 in the year 1398 and before month 6: ',len(temp98[temp98.Year==1397]))
# temp98.groupby('Fin_year')['Symbol'].agg('count')
# print('Number of comoon Symbols in BS98 and Measure 98 in the year 1398: ',len(set(mf.Symbol).intersection(set(temp98.Symbol))))
# print('Number of Symbols in Measure 98 before filtration: ',len(mf))

# %%
# Reading all data and appending
df = pd.DataFrame()
for year in range(1385,1399):
    temp = read_inc_data(year,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)
    temp['data']['year_id'] = year
    df = df.append(temp['data'])

# Creating dict for persian-english column names
Inc_dict = pd.DataFrame(data={'نام اصلی':list(temp['columns_dict'].keys()),'نام استفاده شده':list(temp['columns_dict'].values())})
Inc_dict.to_excel('Inc_columns_dict.xlsx')

df = df[df.Year>=1385]
df = df.drop_duplicates([x for x in list(df.columns) if x is not 'year_id'])

# Handling observations for the same year from different years!
dupped = df[df.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
un_dupped = df[~df.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
firm_sym_dict =dict(zip(dupped.Firm,dupped.Symbol))
dupped = dupped.groupby(['Symbol','Year'],as_index=False).ffill().reindex(dupped.columns, axis=1)
dupped['Symbol'] = dupped.Firm.map(sherkat_namad_dict)
dupped['Year'] = dupped.Fin_year.apply(lambda x: find_year(x))
dupped = dupped.sort_values(by=['Symbol','Year'])
dupped = dupped.drop_duplicates(['Symbol','Year'],keep='last')
df = dupped.append(un_dupped).sort_values(by=['Symbol','Year'])


# Saving Data
for year in range(1385,1399):
    out_name = "IncomeStatement"+str(year)+".csv"
    df_inc = df[df.Year==year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df_inc.to_csv(out_name)

# %%
Inc_dict
df.groupby('Year')['Symbol'].agg('count')
df_inc.head()
# Out:
#                                              نام اصلی  \
# 0                                            نام شرکت
# 1                                                نماد
# 2                                            سال مالی
# 3                                          تاریخ مصوب
# 4                                            ارزش روز
# 5                                              سرمایه
# 6                                         جمع درآمدها
# 7                       بهای تمام شده کالای فروش رفته
# 8   هزینه تامین منابع مالی عملیات لیزینگ (هزینه سو...
# 9                                          سود ناویژه
# 10                   خالص درآمدها و هزینه‌های عملیاتی
# 11                                 سود (زیان) عملیاتی
# 12                                     هزینه‌های مالی
# 13              سود (زیان) تسعیر تسهیلات ارزی دریافتی
# 14                       خالص سایر درآمدها (هزینه‌ها)
# 15                 سود(زیان)فروش دارائیهای زیستی مولد
# ...

# %% [markdown]
# # **Cleaning Cash Flow Statement Data**

# %%
# ## We did not have enough data for 1398. So in this cell we want to see what is happening?!
# df = pd.read_csv('cf98.csv')
# len(df)
# temp = read_cf_data(year=1398,path=r"C:\Users\Mahdi\OneDrive\Master Thesis\Data",sherkat_namad_dict=sherkat_namad_dict)['data_short']
# temp['year'] = temp.Fin_year.apply(lambda x: x.year)
# temp98 = temp[temp.year==1398]
# mf = pd.read_csv('Measures1398.csv',index_col=0).drop_duplicates()

# print('Number of Symbols in BS98: ',len(temp.Symbol.drop_duplicates()))
# temp.groupby('year')['Symbol'].agg('count').iloc[-5:]
# print('Number of Symbols in BS98 in the year 1398 and before month 6: ',len(temp98[temp98.Year==1397]))
# temp98.groupby('Fin_year')['Symbol'].agg('count')
# print('Number of comoon Symbols in BS98 and Measure 98 in the year 1398: ',len(set(mf.Symbol).intersection(set(temp98.Symbol))))
# print('Number of Symbols in Measure 98 before filtration: ',len(mf))

# %%
path = r"C:\Users\Mahdi\OneDrive\Master Thesis\Data"

df_short = pd.DataFrame()
df_all = pd.DataFrame()

for year in range(1385,1399):
    temp = read_cf_data(year=year,path=path,sherkat_namad_dict=sherkat_namad_dict)
    temp['data_short']['year_id'] = year
    df_short = df_short.append(temp['data_short'])
    df_all = df_all.append(temp['data_all'])    
    
CF_dict = pd.DataFrame(data={'نام اصلی':list(temp['columns_dict'].keys()),'نام استفاده شده':list(temp['columns_dict'].values())})
CF_dict.to_excel('CF_columns_dict.xlsx')    

df_short = df_short[df_short.Year>=1385]
df_short = df_short.drop_duplicates([x for x in list(df_short.columns) if x is not 'year_id'])

# Handling observations for the same year from different years!
dupped = df_short[df_short.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
un_dupped = df_short[~df_short.duplicated(['Symbol','Year'],keep=False)].sort_values(by=['Symbol','Year','year_id'])
firm_sym_dict =dict(zip(dupped.Firm,dupped.Symbol))
dupped = dupped.groupby(['Symbol','Year'],as_index=False).ffill().reindex(dupped.columns, axis=1)
dupped['Symbol'] = dupped.Firm.map(sherkat_namad_dict)
dupped['Year'] = dupped.Fin_year.apply(lambda x: find_year(x))
dupped = dupped.sort_values(by=['Symbol','Year'])
dupped = dupped.drop_duplicates(['Symbol','Year'],keep='last')
df_short = dupped.append(un_dupped).sort_values(by=['Symbol','Year'])


for year in range(1385,1399):
    out_name_short = 'CashFlow'+str(year)+'.csv'
    out_name_all = 'CashFlow'+str(year)+'_all.csv'
    temp_short = df_short[df_short.Year==year]
    temp_all = df_all[df_all.Year==year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    temp_short.to_csv(out_name_short)
    temp_all.to_csv(out_name_all)

# %%
CF_dict
df_short.groupby('Year')['Symbol'].agg('count')
temp_short.head()
# Out:
#                                 نام اصلی         نام استفاده شده
# 0                                   شرکت                    Firm
# 1                                   نماد                  Symbol
# 2                               سال مالی                Fin_year
# 3                             تاریخ مصوب            Approve_date
# 4               خالص افزایش کاهش وجه نقد          Change_in_cash
# 5            مانده وجه نقد در انتهای سال       End_cash_position
# 6            مانده وجه نقد در ابتدای سال  Begining_cash_position
# 7                    جریان خالص وجوه نقد     Operating_cash_flow
# 8    جمع جریان خالص فعالیتهای تامین مالی     Financing_cash_flow
# 9  جمع جریان خالص فعالیتهای سرمایه گذاری     Investing_cash_flow
# Year
# 1385    405
# 1386    358
# 1387    393
# 1388    412
# 1389    447
# 1390    516
# 1391    493
# 1392    560
# 1393    574
# 1394    603
# 1395    598
# 1396    616
# 1397    644
# 1398    134
# Name: Symbol, dtype: int64
# ...

# %% [markdown]
# # **Cleaning Dividend Data**

# %%
os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
dividend_data = pd.read_excel('Annual_div-98.xlsx')
dividend_data = dividend_data.sort_values(by='year')
dividend_data = dividend_data[dividend_data.year>=1385]
dividend_data['firm'] = dividend_data['firm'].apply(lambda x: convert_ar_characters(x))
dividend_data['symbol'] = dividend_data['firm'].map(sherkat_namad_dict,na_action='ignore')
dividend_data['industry'] = dividend_data['industry'].apply(lambda x: convert_ar_characters(x))
dividend_data.rename(columns={'capital':'Equity','symbol':'Symbol','firm':'Firm','year':'Year','industry':'Industry','ind_id':'Ind_id',
                             'earning':'Earning','dividend':'Dividend','payout':'Payout','eps':'EPS','dps':'DPS'},inplace=True)

dividend_data = dividend_data[['Year', 'Firm', 'Symbol', 'Industry', 'Earning','Dividend','Payout','EPS', 'DPS', 'Equity',
                               'adj_eps', 'adj_dps', 'adj_earning', 'adj_dividend', 'cpi','Ind_id']]

# %%
# Unit converter
for x in ['Earning','Dividend','adj_earning', 'adj_dividend']:
    dividend_data[x] = dividend_data[x]*1000

dividend_data['Payout'] = np.round(dividend_data['Dividend']/dividend_data['Earning'],4)

# %%
for year in range(1385,1398):
    out_name = 'Dividend'+str(year)+'.csv'
    df = dividend_data[dividend_data.Year == year]
    os.chdir(r"C:\Users\Mahdi\OneDrive\Master Thesis\Data")
    df.to_csv(out_name)

# %%
dividend_data.groupby('Year')['Symbol'].agg('count')
df.head()
# Out:
# Year
# 1385    349
# 1386    343
# 1387    329
# 1388    341
# 1389    361
# 1390    432
# 1391    475
# 1392    519
# 1393    549
# 1394    583
# 1395    603
# 1396    607
# 1397    458
# Name: Symbol, dtype: int64
#       Year                 Firm Symbol  \
# 2360  1397      ایرکا پارت صنعت   خکار
# 7529  1397  فولاد کاوه جنوب کیش   کاوه
# 7051  1397            البرزدارو  دالبر
# 1884  1397          مهرکام پارس   خمهر
# 4603  1397             بیمه ملت    ملت
#
#                                       Industry        Earning  Dividend  \
# 2360                        خودرو و ساخت قطعات    4250.000000    1000.0
# 7529                               فلزات اساسی  944900.000000  990000.0
# 7051                     مواد و محصولات دارویی  151218.000000  133920.0
# 1884                        خودرو و ساخت قطعات  -43379.228791       0.0
# 4603  بیمه وصندوق بازنشستگی به جزتامین اجتماعی   86070.000000   71250.0
#
#       Payout  EPS  DPS      Equity  adj_eps  adj_dps  adj_earning  \
# ...
